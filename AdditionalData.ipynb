# %% [markdown]
# ##Load Data

# %%
# !nvidia-smi
# Out:
# Fri Jul  7 06:49:18 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   32C    P0    26W / 300W |      0MiB / 16384MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Copy datasets
# !cp /content/drive/MyDrive/Datasets/Datasets2.zip .

# %%
# !unzip '/content/Datasets2.zip' -d '/content/'
# Out:
# Archive:  /content/Datasets2.zip
#    creating: /content/Datasets2/
#    creating: /content/Datasets2/Fiber/
#   inflating: /content/Datasets2/Fiber/20200221-154325-667.jpg
#   inflating: /content/Datasets2/Fiber/20200327-170511-135.jpg
#   inflating: /content/Datasets2/Fiber/20200511-171215-748.jpg
#   inflating: /content/Datasets2/Fiber/20200511-171216-435.jpg
#   inflating: /content/Datasets2/Fiber/20200521-175302-30.jpg
#   inflating: /content/Datasets2/Fiber/20200521-191919-998.jpg
#   inflating: /content/Datasets2/Fiber/20200521-193711-111.jpg
#   inflating: /content/Datasets2/Fiber/20200521-193929-583.jpg
#   inflating: /content/Datasets2/Fiber/20200521-194637-852.jpg
#   inflating: /content/Datasets2/Fiber/20200521-200100-417.jpg
#   inflating: /content/Datasets2/Fiber/20200602-164843-952.jpg
#   inflating: /content/Datasets2/Fiber/20200602-164844-358.jpg
#   inflating: /content/Datasets2/Fiber/20200602-165130-765.jpg
#   inflating: /content/Datasets2/Fiber/20200602-165131-133.jpg
#   inflating: /content/Datasets2/Fiber/20200602-165131-541.jpg
#   inflating: /content/Datasets2/Fiber/20200602-170241-421.jpg
#   inflating: /content/Datasets2/Fiber/20200602-170517-447.jpg
#   inflating: /content/Datasets2/Fiber/20200602-170731-775.jpg
#   inflating: /content/Datasets2/Fiber/20200602-170732-547.jpg
#   inflating: /content/Datasets2/Fiber/20200602-171452-16.jpg
#   inflating: /content/Datasets2/Fiber/20200602-171940-851.jpg
#   inflating: /content/Datasets2/Fiber/20200602-171941-501.jpg
#   inflating: /content/Datasets2/Fiber/20200602-172357-479.jpg
#   inflating: /content/Datasets2/Fiber/20200602-172358-166.jpg
#   inflating: /content/Datasets2/Fiber/20200602-172518-255.jpg
#   inflating: /content/Datasets2/Fiber/20200602-172738-255.jpg
#   inflating: /content/Datasets2/Fiber/20200602-172835-998.jpg
#   inflating: /content/Datasets2/Fiber/20200602-173855-735.jpg
#   inflating: /content/Datasets2/Fiber/20200602-174202-864.jpg
#   inflating: /content/Datasets2/Fiber/20200608-181051-990.jpg
#   inflating: /content/Datasets2/Fiber/20200608-181453-122.jpg
#   inflating: /content/Datasets2/Fiber/20200608-181819-56.jpg
#   inflating: /content/Datasets2/Fiber/20200608-182345-742.jpg
#   inflating: /content/Datasets2/Fiber/20200608-182745-157.jpg
#   inflating: /content/Datasets2/Fiber/20200608-190200-766.jpg
#   inflating: /content/Datasets2/Fiber/20200608-192606-511.jpg
#   inflating: /content/Datasets2/Fiber/20200608-192607-626.jpg
#   inflating: /content/Datasets2/Fiber/20200608-192716-259.jpg
#   inflating: /content/Datasets2/Fiber/20200608-192716-992.jpg
#   inflating: /content/Datasets2/Fiber/20200608-193741-999.jpg
#   inflating: /content/Datasets2/Fiber/20200608-194231-244.jpg
#   inflating: /content/Datasets2/Fiber/20200608-194414-712.jpg
#   inflating: /content/Datasets2/Fiber/20200608-194524-931.jpg
#   inflating: /content/Datasets2/Fiber/20200608-195028-254.jpg
#   inflating: /content/Datasets2/Fiber/20200608-195227-209.jpg
#   inflating: /content/Datasets2/Fiber/20200608-201503-675.jpg
#   inflating: /content/Datasets2/Fiber/20200608-202421-271.jpg
#   inflating: /content/Datasets2/Fiber/20200608-202639-398.jpg
#   inflating: /content/Datasets2/Fiber/20200608-202640-54.jpg
#   inflating: /content/Datasets2/Fiber/20200608-203055-933.jpg
#   inflating: /content/Datasets2/Fiber/20200608-203246-688.jpg
#   inflating: /content/Datasets2/Fiber/20200608-203246-996.jpg
#   inflating: /content/Datasets2/Fiber/20200608-203247-279.jpg
#   inflating: /content/Datasets2/Fiber/20200608-203551-726.jpg
#   inflating: /content/Datasets2/Fiber/20200608-203552-266.jpg
#   inflating: /content/Datasets2/Fiber/20200608-203604-342.jpg
#   inflating: /content/Datasets2/Fiber/20200611-112521-258.jpg
#   inflating: /content/Datasets2/Fiber/20200611-112521-457.jpg
#   inflating: /content/Datasets2/Fiber/20200611-112521-77.jpg
#   inflating: /content/Datasets2/Fiber/20200611-113649-452.jpg
#   inflating: /content/Datasets2/Fiber/20200611-113649-620.jpg
#   inflating: /content/Datasets2/Fiber/20200611-113649-804.jpg
#   inflating: /content/Datasets2/Fiber/20200611-113746-898.jpg
#   inflating: /content/Datasets2/Fiber/20200611-113747-272.jpg
#   inflating: /content/Datasets2/Fiber/20200611-113747-647.jpg
#   inflating: /content/Datasets2/Fiber/20200611-114305-689.jpg
#   inflating: /content/Datasets2/Fiber/20200611-114305-889.jpg
#   inflating: /content/Datasets2/Fiber/20200611-114306-105.jpg
#   inflating: /content/Datasets2/Fiber/20200611-114601-108.jpg
#   inflating: /content/Datasets2/Fiber/20200611-114601-317.jpg
#   inflating: /content/Datasets2/Fiber/20200611-114601-550.jpg
#   inflating: /content/Datasets2/Fiber/20200611-114810-172.jpg
#   inflating: /content/Datasets2/Fiber/20200611-114810-371.jpg
#   inflating: /content/Datasets2/Fiber/20200611-114810-611.jpg
#   inflating: /content/Datasets2/Fiber/20200611-115224-705.jpg
#   inflating: /content/Datasets2/Fiber/20200611-115224-882.jpg
#   inflating: /content/Datasets2/Fiber/20200611-115225-65.jpg
#   inflating: /content/Datasets2/Fiber/20200611-120109-230.jpg
#   inflating: /content/Datasets2/Fiber/20200611-121113-562.jpg
#   inflating: /content/Datasets2/Fiber/20200611-123105-261.jpg
#   inflating: /content/Datasets2/Fiber/20200611-123105-485.jpg
#   inflating: /content/Datasets2/Fiber/20200611-124256-343.jpg
#   inflating: /content/Datasets2/Fiber/20200611-124746-382.jpg
#   inflating: /content/Datasets2/Fiber/20200611-124746-545.jpg
#   inflating: /content/Datasets2/Fiber/20200611-124746-714.jpg
#   inflating: /content/Datasets2/Fiber/20200611-130043-389.jpg
#   inflating: /content/Datasets2/Fiber/20200611-130043-585.jpg
#   inflating: /content/Datasets2/Fiber/20200611-130043-806.jpg
#   inflating: /content/Datasets2/Fiber/20200611-130121-317.jpg
#   inflating: /content/Datasets2/Fiber/20200611-130121-548.jpg
#   inflating: /content/Datasets2/Fiber/20200611-130121-92.jpg
#   inflating: /content/Datasets2/Fiber/20200611-130206-709.jpg
#   inflating: /content/Datasets2/Fiber/20200611-130206-917.jpg
#   inflating: /content/Datasets2/Fiber/20200611-130207-152.jpg
#   inflating: /content/Datasets2/Fiber/20200611-130316-568.jpg
#   inflating: /content/Datasets2/Fiber/20200611-130758-514.jpg
#   inflating: /content/Datasets2/Fiber/20200611-130910-341.jpg
#   inflating: /content/Datasets2/Fiber/20200611-130911-19.jpg
#   inflating: /content/Datasets2/Fiber/20200611-130911-505.jpg
#   inflating: /content/Datasets2/Fiber/20200611-131301-475.jpg
#   inflating: /content/Datasets2/Fiber/20200611-131301-675.jpg
#   inflating: /content/Datasets2/Fiber/20200611-131301-881.jpg
#   inflating: /content/Datasets2/Fiber/20200611-131455-187.jpg
#   inflating: /content/Datasets2/Fiber/20200611-132225-343.jpg
#   inflating: /content/Datasets2/Fiber/20200611-135207-872.jpg
#   inflating: /content/Datasets2/Fiber/20200611-140837-116.jpg
#   inflating: /content/Datasets2/Fiber/20200611-141312-711.jpg
#   inflating: /content/Datasets2/Fiber/20200611-141630-417.jpg
#   inflating: /content/Datasets2/Fiber/20200611-143238-406.jpg
#   inflating: /content/Datasets2/Fiber/20200611-143238-789.jpg
#   inflating: /content/Datasets2/Fiber/20200611-143647-824.jpg
#   inflating: /content/Datasets2/Fiber/20200611-144239-738.jpg
#   inflating: /content/Datasets2/Fiber/20200611-144240-362.jpg
#   inflating: /content/Datasets2/Fiber/20200611-144240-42.jpg
#   inflating: /content/Datasets2/Fiber/20200611-144617-208.jpg
#   inflating: /content/Datasets2/Fiber/20200611-144617-392.jpg
#   inflating: /content/Datasets2/Fiber/20200611-144617-568.jpg
#   inflating: /content/Datasets2/Fiber/20200611-144728-255.jpg
#   inflating: /content/Datasets2/Fiber/20200611-144728-75.jpg
#   inflating: /content/Datasets2/Fiber/20200611-144730-783.jpg
#   inflating: /content/Datasets2/Fiber/20200611-145012-647.jpg
#   inflating: /content/Datasets2/Fiber/20200611-145012-838.jpg
#   inflating: /content/Datasets2/Fiber/20200611-145013-15.jpg
#   inflating: /content/Datasets2/Fiber/20200611-145116-802.jpg
#   inflating: /content/Datasets2/Fiber/20200611-145421-413.jpg
#   inflating: /content/Datasets2/Fiber/20200611-145421-588.jpg
#   inflating: /content/Datasets2/Fiber/20200611-145945-518.jpg
#   inflating: /content/Datasets2/Fiber/20200611-145945-806.jpg
#   inflating: /content/Datasets2/Fiber/20200611-150404-800.jpg
#   inflating: /content/Datasets2/Fiber/20200611-150548-184.jpg
#   inflating: /content/Datasets2/Fiber/20200611-150650-352.jpg
#   inflating: /content/Datasets2/Fiber/20200611-150650-652.jpg
#   inflating: /content/Datasets2/Fiber/20200611-150810-582.jpg
#   inflating: /content/Datasets2/Fiber/20200611-151122-645.jpg
#   inflating: /content/Datasets2/Fiber/20200611-151312-157.jpg
#   inflating: /content/Datasets2/Fiber/20200611-151355-130.jpg
#   inflating: /content/Datasets2/Fiber/20200611-152615-887.jpg
#   inflating: /content/Datasets2/Fiber/20200611-152616-219.jpg
#   inflating: /content/Datasets2/Fiber/20200611-153754-986.jpg
#   inflating: /content/Datasets2/Fiber/20200611-154746-242.jpg
#   inflating: /content/Datasets2/Fiber/20200611-154746-85.jpg
#   inflating: /content/Datasets2/Fiber/20200611-155325-17.jpg
#   inflating: /content/Datasets2/Fiber/20200611-160415-684.jpg
#   inflating: /content/Datasets2/Fiber/20200611-160415-983.jpg
#   inflating: /content/Datasets2/Fiber/20200611-160416-292.jpg
#   inflating: /content/Datasets2/Fiber/20200611-162253-675.jpg
#   inflating: /content/Datasets2/Fiber/20200611-162254-11.jpg
#   inflating: /content/Datasets2/Fiber/20200611-162254-347.jpg
#   inflating: /content/Datasets2/Fiber/20200612-114113-827.jpg
#   inflating: /content/Datasets2/Fiber/20200612-114114-216.jpg
#   inflating: /content/Datasets2/Fiber/20200612-114114-596.jpg
#   inflating: /content/Datasets2/Fiber/20200612-114153-392.jpg
#   inflating: /content/Datasets2/Fiber/20200612-114153-720.jpg
#   inflating: /content/Datasets2/Fiber/20200612-114154-42.jpg
#   inflating: /content/Datasets2/Fiber/20200612-114310-175.jpg
#   inflating: /content/Datasets2/Fiber/20200612-114310-735.jpg
#   inflating: /content/Datasets2/Fiber/20200612-114311-215.jpg
#   inflating: /content/Datasets2/Fiber/20200612-114746-745.jpg
#   inflating: /content/Datasets2/Fiber/20200612-114747-137.jpg
#   inflating: /content/Datasets2/Fiber/20200612-114747-521.jpg
#   inflating: /content/Datasets2/Fiber/20200612-114827-432.jpg
#   inflating: /content/Datasets2/Fiber/20200612-114827-716.jpg
#   inflating: /content/Datasets2/Fiber/20200612-114828-36.jpg
#   inflating: /content/Datasets2/Fiber/20200612-114900-740.jpg
#   inflating: /content/Datasets2/Fiber/20200612-114901-304.jpg
#   inflating: /content/Datasets2/Fiber/20200612-114901-40.jpg
#   inflating: /content/Datasets2/Fiber/20200612-114929-255.jpg
#   inflating: /content/Datasets2/Fiber/20200612-114929-676.jpg
#   inflating: /content/Datasets2/Fiber/20200612-114930-61.jpg
#   inflating: /content/Datasets2/Fiber/20200612-115022-236.jpg
#   inflating: /content/Datasets2/Fiber/20200612-115022-532.jpg
#   inflating: /content/Datasets2/Fiber/20200612-115022-912.jpg
#   inflating: /content/Datasets2/Fiber/20200612-121323-502.jpg
#   inflating: /content/Datasets2/Fiber/20200612-121323-806.jpg
#   inflating: /content/Datasets2/Fiber/20200612-121324-138.jpg
#   inflating: /content/Datasets2/Fiber/20200612-130908-934.jpg
#   inflating: /content/Datasets2/Fiber/20200612-130909-246.jpg
#   inflating: /content/Datasets2/Fiber/20200612-130909-536.jpg
#   inflating: /content/Datasets2/Fiber/20200612-132358-840.jpg
#   inflating: /content/Datasets2/Fiber/20200612-132359-28.jpg
#   inflating: /content/Datasets2/Fiber/20200612-132359-348.jpg
#   inflating: /content/Datasets2/Fiber/20200612-144633-664.jpg
#   inflating: /content/Datasets2/Fiber/20200612-144904-754.jpg
#   inflating: /content/Datasets2/Fiber/20200612-144947-734.jpg
#   inflating: /content/Datasets2/Fiber/20200612-145953-860.jpg
#   inflating: /content/Datasets2/Fiber/20200612-150211-269.jpg
#   inflating: /content/Datasets2/Fiber/20200612-150335-160.jpg
#   inflating: /content/Datasets2/Fiber/20200612-150835-910.jpg
#   inflating: /content/Datasets2/Fiber/20200612-151227-549.jpg
#   inflating: /content/Datasets2/Fiber/20200612-151421-264.jpg
#   inflating: /content/Datasets2/Fiber/20200612-151506-964.jpg
#   inflating: /content/Datasets2/Fiber/20200612-152911-446.jpg
#   inflating: /content/Datasets2/Fiber/20200612-153058-17.jpg
#   inflating: /content/Datasets2/Fiber/20200612-155645-358.jpg
#   inflating: /content/Datasets2/Fiber/20200612-165352-843.jpg
#   inflating: /content/Datasets2/Fiber/20200612-165353-18.jpg
#   inflating: /content/Datasets2/Fiber/20200612-165353-202.jpg
#   inflating: /content/Datasets2/Fiber/20200612-172756-272.jpg
#   inflating: /content/Datasets2/Fiber/20200612-172756-433.jpg
#   inflating: /content/Datasets2/Fiber/20200612-172756-633.jpg
#   inflating: /content/Datasets2/Fiber/20200612-181317-552.jpg
#   inflating: /content/Datasets2/Fiber/20200612-181317-864.jpg
#   inflating: /content/Datasets2/Fiber/20200612-181318-184.jpg
#   inflating: /content/Datasets2/Fiber/20200612-181431-115.jpg
#   inflating: /content/Datasets2/Fiber/20200612-181431-403.jpg
#   inflating: /content/Datasets2/Fiber/20200612-181431-716.jpg
#   inflating: /content/Datasets2/Fiber/20200612-181616-15.jpg
#   inflating: /content/Datasets2/Fiber/20200612-181616-319.jpg
#   inflating: /content/Datasets2/Fiber/20200612-181616-671.jpg
#   inflating: /content/Datasets2/Fiber/20200612-181655-731.jpg
#   inflating: /content/Datasets2/Fiber/20200612-181656-15.jpg
#   inflating: /content/Datasets2/Fiber/20200612-181656-323.jpg
#   inflating: /content/Datasets2/Fiber/20200612-182024-899.jpg
#   inflating: /content/Datasets2/Fiber/20200612-182025-445.jpg
#   inflating: /content/Datasets2/Fiber/20200612-182051-933.jpg
#   inflating: /content/Datasets2/Fiber/20200612-182613-887.jpg
#   inflating: /content/Datasets2/Fiber/20200612-182648-383.jpg
#   inflating: /content/Datasets2/Fiber/20200612-182648-85.jpg
#   inflating: /content/Datasets2/Fiber/20200612-182744-416.jpg
#   inflating: /content/Datasets2/Fiber/20200612-182744-675.jpg
#   inflating: /content/Datasets2/Fiber/20200612-182744-994.jpg
#   inflating: /content/Datasets2/Fiber/20200612-182942-646.jpg
#   inflating: /content/Datasets2/Fiber/20200612-182942-909.jpg
#   inflating: /content/Datasets2/Fiber/20200612-182943-250.jpg
#   inflating: /content/Datasets2/Fiber/20200612-183220-917.jpg
#   inflating: /content/Datasets2/Fiber/20200612-183221-149.jpg
#   inflating: /content/Datasets2/Fiber/20200612-183221-429.jpg
#   inflating: /content/Datasets2/Fiber/20200612-183255-381.jpg
#   inflating: /content/Datasets2/Fiber/20200612-183255-692.jpg
#   inflating: /content/Datasets2/Fiber/20200612-183255-77.jpg
#   inflating: /content/Datasets2/Fiber/20200612-183510-679.jpg
#   inflating: /content/Datasets2/Fiber/20200612-183510-960.jpg
#   inflating: /content/Datasets2/Fiber/20200612-183511-271.jpg
#   inflating: /content/Datasets2/Fiber/20200612-184310-396.jpg
#   inflating: /content/Datasets2/Fiber/20200612-184311-68.jpg
#   inflating: /content/Datasets2/Fiber/20200612-184450-792.jpg
#   inflating: /content/Datasets2/Fiber/20200612-184451-131.jpg
#   inflating: /content/Datasets2/Fiber/20200612-184451-487.jpg
#   inflating: /content/Datasets2/Fiber/20200612-184518-555.jpg
#   inflating: /content/Datasets2/Fiber/20200612-184518-836.jpg
#   inflating: /content/Datasets2/Fiber/20200612-184519-123.jpg
#   inflating: /content/Datasets2/Fiber/20200612-184654-140.jpg
#   inflating: /content/Datasets2/Fiber/20200612-185538-435.jpg
#   inflating: /content/Datasets2/Fiber/20200612-185726-270.jpg
#   inflating: /content/Datasets2/Fiber/20200612-185813-761.jpg
#   inflating: /content/Datasets2/Fiber/20200612-185814-466.jpg
#   inflating: /content/Datasets2/Fiber/20200612-185814-86.jpg
#   inflating: /content/Datasets2/Fiber/20200612-190727-42.jpg
#   inflating: /content/Datasets2/Fiber/20200612-191033-108.jpg
#   inflating: /content/Datasets2/Fiber/20200612-191033-500.jpg
#   inflating: /content/Datasets2/Fiber/20200612-191033-881.jpg
#   inflating: /content/Datasets2/Fiber/20200613-141302-911.jpg
#   inflating: /content/Datasets2/Fiber/20200613-141502-233.jpg
#   inflating: /content/Datasets2/Fiber/20200613-141750-704.jpg
#   inflating: /content/Datasets2/Fiber/20200613-141750-961.jpg
#   inflating: /content/Datasets2/Fiber/20200613-141845-861.jpg
#   inflating: /content/Datasets2/Fiber/20200613-141846-429.jpg
#   inflating: /content/Datasets2/Fiber/20200613-142439-757.jpg
#   inflating: /content/Datasets2/Fiber/20200613-143017-659.jpg
#   inflating: /content/Datasets2/Fiber/20200613-143050-799.jpg
#   inflating: /content/Datasets2/Fiber/20200613-144017-128.jpg
#   inflating: /content/Datasets2/Fiber/20200613-144413-205.jpg
#   inflating: /content/Datasets2/Fiber/20200613-145613-548.jpg
#   inflating: /content/Datasets2/Fiber/20200613-145613-820.jpg
#   inflating: /content/Datasets2/Fiber/20200613-145614-97.jpg
#   inflating: /content/Datasets2/Fiber/20200613-145658-256.jpg
#   inflating: /content/Datasets2/Fiber/20200613-145658-799.jpg
#   inflating: /content/Datasets2/Fiber/N1.1C1.2_300mmW.jpg
#   inflating: /content/Datasets2/Fiber/N1.1C1.2_300mmW1.jpg
#   inflating: /content/Datasets2/Fiber/N1.1C1.2_300mmW2.jpg
#   inflating: /content/Datasets2/Fiber/N1.1K1_300mmW_T.jpg
#   inflating: /content/Datasets2/Fiber/N1.1K1_300mmW_T1.jpg
#   inflating: /content/Datasets2/Fiber/N1.1K1_300mmW_T2.jpg
#   inflating: /content/Datasets2/Fiber/N1.1P3.3_300mm1B.jpg
#   inflating: /content/Datasets2/Fiber/N1.1P3.3_300mm2B.jpg
#   inflating: /content/Datasets2/Fiber/N1.1P3.3_300mmB.jpg
#   inflating: /content/Datasets2/Fiber/N1.1T1_300mmB.jpg
#   inflating: /content/Datasets2/Fiber/N1.1T1_300mmB1.jpg
#   inflating: /content/Datasets2/Fiber/N1.1T1_300mmB2.jpg
#   inflating: /content/Datasets2/Fiber/N1.2P3.3_300mm1B.jpg
#   inflating: /content/Datasets2/Fiber/N1.2P3.3_300mm2B.jpg
#   inflating: /content/Datasets2/Fiber/N1.2P3.3_300mmB.jpg
#   inflating: /content/Datasets2/Fiber/N1.3P3.3_300mm1B.jpg
#   inflating: /content/Datasets2/Fiber/N1.3P3.3_300mm2B.jpg
#   inflating: /content/Datasets2/Fiber/N1.5T1_300mmB.jpg
#   inflating: /content/Datasets2/Fiber/N1.5T1_300mmB1.jpg
#   inflating: /content/Datasets2/Fiber/N1.5T1_300mmB2.jpg
#   inflating: /content/Datasets2/Fiber/N10K2_20mmB.jpg
#   inflating: /content/Datasets2/Fiber/N10K2_20mmB1.jpg
#   inflating: /content/Datasets2/Fiber/N10K2_20mmB2.jpg
#   inflating: /content/Datasets2/Fiber/N10R1_300mmW_T - Copy (2).jpg
#   inflating: /content/Datasets2/Fiber/N10R1_300mmW_T - Copy - Copy.jpg
#   inflating: /content/Datasets2/Fiber/N10R1_300mmW_T1 - Copy (2).jpg
#   inflating: /content/Datasets2/Fiber/N10R1_300mmW_T1 - Copy - Copy.jpg
#   inflating: /content/Datasets2/Fiber/N10R1_300mmW_T2 - Copy.jpg
#   inflating: /content/Datasets2/Fiber/N11K2_20mmB.jpg
#   inflating: /content/Datasets2/Fiber/N11K2_20mmB1.jpg
#   inflating: /content/Datasets2/Fiber/N11K2_20mmB2.jpg
#   inflating: /content/Datasets2/Fiber/N11K2_20mmB3.jpg
#   inflating: /content/Datasets2/Fiber/N11K3_300mmBL - Copy.jpg
#   inflating: /content/Datasets2/Fiber/N11K3_300mmBL1 - Copy.jpg
#   inflating: /content/Datasets2/Fiber/N11K3_300mmBL2 - Copy.jpg
#   inflating: /content/Datasets2/Fiber/N11P1_20mmB.jpg
#   inflating: /content/Datasets2/Fiber/N11P1_20mmB1.jpg
#   inflating: /content/Datasets2/Fiber/N11P1_20mmB3.jpg
#   inflating: /content/Datasets2/Fiber/N11T2.1_300mm1B.jpg
#   inflating: /content/Datasets2/Fiber/N11T2.1_300mm2B.jpg
#   inflating: /content/Datasets2/Fiber/N11T2.1_300mm3B.jpg
#   inflating: /content/Datasets2/Fiber/N11T2.1_300mmB.jpg
#   inflating: /content/Datasets2/Fiber/N12.1P1_20mmBr.jpg
#   inflating: /content/Datasets2/Fiber/N12.2P1_20mmBr.jpg
#   inflating: /content/Datasets2/Fiber/N12.2P1_20mmBr2.jpg
#   inflating: /content/Datasets2/Fiber/N12C3_300mmB.jpg
#   inflating: /content/Datasets2/Fiber/N12C3_300mmB3.jpg
#   inflating: /content/Datasets2/Fiber/N12C3_300mmB4.jpg
#   inflating: /content/Datasets2/Fiber/N12K2_20mmW2(1).jpg
#   inflating: /content/Datasets2/Fiber/N12K2_20mmW2.jpg
#   inflating: /content/Datasets2/Fiber/N12K2_20mmW3(1).jpg
#   inflating: /content/Datasets2/Fiber/N12K2_20mmW3.jpg
#   inflating: /content/Datasets2/Fiber/N12K2_20mmW4(1).jpg
#   inflating: /content/Datasets2/Fiber/N12P1_20mmBr1.jpg
#   inflating: /content/Datasets2/Fiber/N12P1_20mmBr2.jpg
#   inflating: /content/Datasets2/Fiber/N13K2_20mmB(1).jpg
#   inflating: /content/Datasets2/Fiber/N13K2_20mmB.jpg
#   inflating: /content/Datasets2/Fiber/N13K2_20mmB1(1).jpg
#   inflating: /content/Datasets2/Fiber/N13K2_20mmB1.jpg
#   inflating: /content/Datasets2/Fiber/N13K2_20mmB2.jpg
#   inflating: /content/Datasets2/Fiber/N13K3_300mmB.jpg
#   inflating: /content/Datasets2/Fiber/N13K3_300mmB2.jpg
#   inflating: /content/Datasets2/Fiber/N13P3_300mmW_T - Copy.jpg
#   inflating: /content/Datasets2/Fiber/N13P3_300mmW_T1 - Copy.jpg
#   inflating: /content/Datasets2/Fiber/N13P3_300mmW_T2 - Copy.jpg
#   inflating: /content/Datasets2/Fiber/N13R1_20mmR.jpg
#   inflating: /content/Datasets2/Fiber/N13T2_20mmB1.jpg
#   inflating: /content/Datasets2/Fiber/N13T2_300mmR - Copy.jpg
#   inflating: /content/Datasets2/Fiber/N13T2_300mmR1 - Copy.jpg
#   inflating: /content/Datasets2/Fiber/N13T2_300mmR2 - Copy.jpg
#   inflating: /content/Datasets2/Fiber/N14K3_20mmDB1.jpg
#   inflating: /content/Datasets2/Fiber/N14K3_20mmDB2.jpg
#   inflating: /content/Datasets2/Fiber/N14P3_300mmR - Copy.jpg
#   inflating: /content/Datasets2/Fiber/N14P3_300mmR.jpg
#   inflating: /content/Datasets2/Fiber/N14P3_300mmR1 - Copy.jpg
#   inflating: /content/Datasets2/Fiber/N14P3_300mmR1.jpg
#   inflating: /content/Datasets2/Fiber/N14P3_300mmR2 - Copy.jpg
#   inflating: /content/Datasets2/Fiber/N14T2.3_300mm1B.jpg
#   inflating: /content/Datasets2/Fiber/N14T2.3_300mmB.jpg
#   inflating: /content/Datasets2/Fiber/N15K1_20mmDB.jpg
#   inflating: /content/Datasets2/Fiber/N15K1_20mmDB1.jpg
#   inflating: /content/Datasets2/Fiber/N15K1_20mmDB2.jpg
#   inflating: /content/Datasets2/Fiber/N15K3_20mmDB.jpg
#   inflating: /content/Datasets2/Fiber/N15K3_20mmDB1.jpg
#   inflating: /content/Datasets2/Fiber/N15K3_20mmDB2.jpg
#   inflating: /content/Datasets2/Fiber/N15R1_20mmW.jpg
#   inflating: /content/Datasets2/Fiber/N15R1_20mmW2.jpg
#   inflating: /content/Datasets2/Fiber/N16.1C3_300mmB.jpg
#   inflating: /content/Datasets2/Fiber/N16.2C3_300mmB.jpg
#   inflating: /content/Datasets2/Fiber/N16.2C3_300mmB1.jpg
#   inflating: /content/Datasets2/Fiber/N16.2C3_300mmB2.jpg
#   inflating: /content/Datasets2/Fiber/N16R1_20mmBr.jpg
#   inflating: /content/Datasets2/Fiber/N16R1_20mmBr2.jpg
#   inflating: /content/Datasets2/Fiber/N17-18R1_20mmB_Br.jpg
#   inflating: /content/Datasets2/Fiber/N17-18R1_20mmB_Br2.jpg
#   inflating: /content/Datasets2/Fiber/N17.1R1_300mmB.jpg
#   inflating: /content/Datasets2/Fiber/N17.1R1_300mmB1.jpg
#   inflating: /content/Datasets2/Fiber/N17.1R1_300mmB2.jpg
#   inflating: /content/Datasets2/Fiber/N17K1_300mmR.jpg
#   inflating: /content/Datasets2/Fiber/N17K1_300mmR1.jpg
#   inflating: /content/Datasets2/Fiber/N17K1_300mmR2.jpg
#   inflating: /content/Datasets2/Fiber/N17R3_300mmB.jpg
#   inflating: /content/Datasets2/Fiber/N18.1R1_300mmW_T.jpg
#   inflating: /content/Datasets2/Fiber/N18.1R1_300mmW_T1.jpg
#   inflating: /content/Datasets2/Fiber/N18.1R1_300mmW_T2.jpg
#   inflating: /content/Datasets2/Fiber/N19-21R1.2_20mmR_B1.jpg
#   inflating: /content/Datasets2/Fiber/N19-21R1.2_20mmR_B2.jpg
#   inflating: /content/Datasets2/Fiber/N19-21R1.2_20mmR_B3.jpg
#   inflating: /content/Datasets2/Fiber/N19C2_300mmB.jpg
#   inflating: /content/Datasets2/Fiber/N19C2_300mmB1.jpg
#   inflating: /content/Datasets2/Fiber/N19P3_20mmDB1.jpg
#   inflating: /content/Datasets2/Fiber/N1C2_300mmB.jpg
#   inflating: /content/Datasets2/Fiber/N1C3.2_20mmDB.jpg
#   inflating: /content/Datasets2/Fiber/N1C3.2_20mmDB1.jpg
#   inflating: /content/Datasets2/Fiber/N1C3.2_20mmDB2.jpg
#   inflating: /content/Datasets2/Fiber/N1C3.2_300mmB.jpg
#   inflating: /content/Datasets2/Fiber/N1C3.2_300mmB1.jpg
#   inflating: /content/Datasets2/Fiber/N1C3.2_300mmB2.jpg
#   inflating: /content/Datasets2/Fiber/N1C3.2_300mmB3.jpg
#   inflating: /content/Datasets2/Fiber/N1C3_20mmB.jpg
#   inflating: /content/Datasets2/Fiber/N1C3_20mmB1.jpg
#   inflating: /content/Datasets2/Fiber/N1C3_20mmB2.jpg
#   inflating: /content/Datasets2/Fiber/N1K1_300mmW.jpg
#   inflating: /content/Datasets2/Fiber/N1K1_300mmW1.jpg
#   inflating: /content/Datasets2/Fiber/N1K1_300mmW2.jpg
#   inflating: /content/Datasets2/Fiber/N1K3_20mmB.jpg
#   inflating: /content/Datasets2/Fiber/N1K3_20mmB1.jpg
#   inflating: /content/Datasets2/Fiber/N1K3_20mmB2.jpg
#   inflating: /content/Datasets2/Fiber/N1P1.1_300mm1R.jpg
#   inflating: /content/Datasets2/Fiber/N1P1.1_300mm2R.jpg
#   inflating: /content/Datasets2/Fiber/N1P1.1_300mm3R.jpg
#   inflating: /content/Datasets2/Fiber/N1P1.1_300mmR.jpg
#   inflating: /content/Datasets2/Fiber/N1P1.2_20mm1B.jpg
#   inflating: /content/Datasets2/Fiber/N1P1.2_20mm1DB.jpg
#   inflating: /content/Datasets2/Fiber/N1P1.2_20mm2B.jpg
#   inflating: /content/Datasets2/Fiber/N1P1.2_20mm2DB.jpg
#   inflating: /content/Datasets2/Fiber/N1P1.2_20mmB.jpg
#   inflating: /content/Datasets2/Fiber/N1P1.2_20mmDB.jpg
#   inflating: /content/Datasets2/Fiber/N1P1.3_300mm1B.jpg
#   inflating: /content/Datasets2/Fiber/N1P1.3_300mm2B.jpg
#   inflating: /content/Datasets2/Fiber/N1P1.3_300mm3B.jpg
#   inflating: /content/Datasets2/Fiber/N1P1.3_300mm4B.jpg
#   inflating: /content/Datasets2/Fiber/N1P1.3_300mmB.jpg
#   inflating: /content/Datasets2/Fiber/N1P1_20mmB.jpg
#   inflating: /content/Datasets2/Fiber/N1P1_20mmB1.jpg
#   inflating: /content/Datasets2/Fiber/N1P1_20mmB2.jpg
#   inflating: /content/Datasets2/Fiber/N1P1_300mmB.jpg
#   inflating: /content/Datasets2/Fiber/N1P1_300mmB1.jpg
#   inflating: /content/Datasets2/Fiber/N1P1_300mmB2.jpg
#   inflating: /content/Datasets2/Fiber/N1P2.3_300mm2B.jpg
#   inflating: /content/Datasets2/Fiber/N1P2.3_300mmB.jpg
#   inflating: /content/Datasets2/Fiber/N1P3.2_20mm1DB.jpg
#   inflating: /content/Datasets2/Fiber/N1P3.2_20mm2DB.jpg
#   inflating: /content/Datasets2/Fiber/N1P3.2_20mmDB.jpg
#   inflating: /content/Datasets2/Fiber/N1P3.3_300mm2B.jpg
#   inflating: /content/Datasets2/Fiber/N1P3_20mmB.jpg
#   inflating: /content/Datasets2/Fiber/N1P3_20mmB1.jpg
#   inflating: /content/Datasets2/Fiber/N1P3_20mmB2.jpg
#   inflating: /content/Datasets2/Fiber/N1R1.3_20mmB.jpg
#   inflating: /content/Datasets2/Fiber/N1R1.3_20mmB1.jpg
#   inflating: /content/Datasets2/Fiber/N1R1.3_20mmB2.jpg
#   inflating: /content/Datasets2/Fiber/N1R1.3_300mmDB.jpg
#   inflating: /content/Datasets2/Fiber/N1R1.3_300mmDB1.jpg
#   inflating: /content/Datasets2/Fiber/N1R1.3_300mmDB2.jpg
#   inflating: /content/Datasets2/Fiber/N1T1.1_20mm1R - Copy.jpg
#   inflating: /content/Datasets2/Fiber/N1T1.1_20mm2R - Copy.jpg
#   inflating: /content/Datasets2/Fiber/N1T1.1_20mmR - Copy.jpg
#   inflating: /content/Datasets2/Fiber/N1T1.3_20mm1B - Copy.jpg
#   inflating: /content/Datasets2/Fiber/N1T1.3_20mm2B - Copy.jpg
#   inflating: /content/Datasets2/Fiber/N1T1.3_20mmB - Copy.jpg
#   inflating: /content/Datasets2/Fiber/N1T1_200mmDB.jpg
#   inflating: /content/Datasets2/Fiber/N1T1_200mmDB1.jpg
#   inflating: /content/Datasets2/Fiber/N1T1_200mmDB2.jpg
#   inflating: /content/Datasets2/Fiber/N1T2.2_20mm1DB.jpg
#   inflating: /content/Datasets2/Fiber/N1T2.2_20mm2DB.jpg
#   inflating: /content/Datasets2/Fiber/N1T2.2_20mmDB.jpg
#   inflating: /content/Datasets2/Fiber/N1T3.1_20mm1B.jpg
#   inflating: /content/Datasets2/Fiber/N1T3.1_20mm2B.jpg
#   inflating: /content/Datasets2/Fiber/N1T3.1_20mmB.jpg
#   inflating: /content/Datasets2/Fiber/N1T3.3_20mm1DB.jpg
#   inflating: /content/Datasets2/Fiber/N1T3.3_20mm2DB.jpg
#   inflating: /content/Datasets2/Fiber/N1T3.3_20mmDB.jpg
#   inflating: /content/Datasets2/Fiber/N1T3_20mmB.jpg
#   inflating: /content/Datasets2/Fiber/N1T3_20mmB1.jpg
#   inflating: /content/Datasets2/Fiber/N1T3_20mmDB.jpg
#   inflating: /content/Datasets2/Fiber/N1T3_20mmDB1.jpg
#   inflating: /content/Datasets2/Fiber/N2.1C3.2_20mmR.jpg
#   inflating: /content/Datasets2/Fiber/N2.1C3.2_20mmR2.jpg
#   inflating: /content/Datasets2/Fiber/N2.1C3.2_20mmR3.jpg
#   inflating: /content/Datasets2/Fiber/N2.1C3.2_20mmR4.jpg
#   inflating: /content/Datasets2/Fiber/N2.1C3.2_20mmR5.jpg
#   inflating: /content/Datasets2/Fiber/N2.1M1.1_20mmR.jpg
#   inflating: /content/Datasets2/Fiber/N2.1M1.1_20mmR1.jpg
#   inflating: /content/Datasets2/Fiber/N2.1M1.1_20mmR2.jpg
#   inflating: /content/Datasets2/Fiber/N2.1R1_20mmB.jpg
#   inflating: /content/Datasets2/Fiber/N2.1R1_20mmB1.jpg
#   inflating: /content/Datasets2/Fiber/N2.1R1_20mmB2.jpg
#   inflating: /content/Datasets2/Fiber/N2.2C3.2_20mmR.jpg
#   inflating: /content/Datasets2/Fiber/N2.2C3.2_20mmR1.jpg
#   inflating: /content/Datasets2/Fiber/N2.2C3.2_20mmR2.jpg
#   inflating: /content/Datasets2/Fiber/N2.2K3_300mmB.jpg
#   inflating: /content/Datasets2/Fiber/N2.2K3_300mmB1.jpg
#   inflating: /content/Datasets2/Fiber/N2.2K3_300mmB2.jpg
#   inflating: /content/Datasets2/Fiber/N2.2M1.1_20mmR.jpg
#   inflating: /content/Datasets2/Fiber/N2.2M1.1_20mmR1.jpg
#   inflating: /content/Datasets2/Fiber/N2.2M1.1_20mmR2.jpg
#   inflating: /content/Datasets2/Fiber/N2.2P1_300mmB.jpg
#   inflating: /content/Datasets2/Fiber/N2.2R1_20mmB.jpg
#   inflating: /content/Datasets2/Fiber/N2.2R1_20mmB1.jpg
#   inflating: /content/Datasets2/Fiber/N2.2R1_20mmB2.jpg
#   inflating: /content/Datasets2/Fiber/N2.3M1.1_20mmR.jpg
#   inflating: /content/Datasets2/Fiber/N2.3M1.1_20mmR1.jpg
#   inflating: /content/Datasets2/Fiber/N2.4M1.1_20mmR1.jpg
#   inflating: /content/Datasets2/Fiber/N2.4M1.1_20mmR2.jpg
#   inflating: /content/Datasets2/Fiber/N2.5C2.2_20mmBr.jpg
#   inflating: /content/Datasets2/Fiber/N2.5C2.2_20mmBr2.jpg
#   inflating: /content/Datasets2/Fiber/N2.5C2.2_20mmBr3.jpg
#   inflating: /content/Datasets2/Fiber/N2.5M1.1_20mmR.jpg
#   inflating: /content/Datasets2/Fiber/N2.5M1.1_20mmR1.jpg
#   inflating: /content/Datasets2/Fiber/N2.5M1.1_20mmR2.jpg
#   inflating: /content/Datasets2/Fiber/N2.6C2.2_20mmBr.jpg
#   inflating: /content/Datasets2/Fiber/N2.6C2.2_20mmBr1.jpg
#   inflating: /content/Datasets2/Fiber/N2.6C2.2_20mmBr2.jpg
#   inflating: /content/Datasets2/Fiber/N20T2_300mmw_T.jpg
#   inflating: /content/Datasets2/Fiber/N20T2_300mmw_T1.jpg
#   inflating: /content/Datasets2/Fiber/N20T2_300mmw_T2.jpg
#   inflating: /content/Datasets2/Fiber/N21.2P1_20mmW1.jpg
#   inflating: /content/Datasets2/Fiber/N22.1P1_20mmR.jpg
#   inflating: /content/Datasets2/Fiber/N22.1P1_20mmR2.jpg
#   inflating: /content/Datasets2/Fiber/N22.2P1_20mmR.jpg
#   inflating: /content/Datasets2/Fiber/N22.2P1_20mmR2.jpg
#   inflating: /content/Datasets2/Fiber/N22P1_20mmR.jpg
#   inflating: /content/Datasets2/Fiber/N22P1_20mmR1.jpg
#   inflating: /content/Datasets2/Fiber/N22P1_20mmR2.jpg
#   inflating: /content/Datasets2/Fiber/N23.1C2_300mmB.jpg
#   inflating: /content/Datasets2/Fiber/N23.1C2_300mmB2.jpg
#   inflating: /content/Datasets2/Fiber/N23C2_300mmB.jpg
#   inflating: /content/Datasets2/Fiber/N23C2_300mmB1.jpg
#   inflating: /content/Datasets2/Fiber/N23P1_20mmDB.jpg
#   inflating: /content/Datasets2/Fiber/N23P1_20mmDB1.jpg
#   inflating: /content/Datasets2/Fiber/N23P1_20mmDB2.jpg
#   inflating: /content/Datasets2/Fiber/N24C3_300mmB.jpg
#   inflating: /content/Datasets2/Fiber/N24C3_300mmB2.jpg
#   inflating: /content/Datasets2/Fiber/N24C3_300mmB3.jpg
#   inflating: /content/Datasets2/Fiber/N24P1_20mmB.jpg
#   inflating: /content/Datasets2/Fiber/N24P1_20mmB1.jpg
#   inflating: /content/Datasets2/Fiber/N24P1_20mmB2.jpg
#   inflating: /content/Datasets2/Fiber/N25C3_300mmR.jpg
#   inflating: /content/Datasets2/Fiber/N25K2_300mmR.jpg
#   inflating: /content/Datasets2/Fiber/N25K2_300mmR1.jpg
#   inflating: /content/Datasets2/Fiber/N25K2_300mmR2.jpg
#   inflating: /content/Datasets2/Fiber/N25P3_20mmDB.jpg
#   inflating: /content/Datasets2/Fiber/N25T1_300mmW_T.jpg
#   inflating: /content/Datasets2/Fiber/N25T1_300mmW_T1.jpg
#   inflating: /content/Datasets2/Fiber/N25T1_300mmW_T2.jpg
#   inflating: /content/Datasets2/Fiber/N26C2_300mmB.jpg
#   inflating: /content/Datasets2/Fiber/N27C2_300mmB.jpg
#   inflating: /content/Datasets2/Fiber/N27K1_20mmDB.jpg
#   inflating: /content/Datasets2/Fiber/N27K1_20mmDB1.jpg
#   inflating: /content/Datasets2/Fiber/N27K1_20mmDB2.jpg
#   inflating: /content/Datasets2/Fiber/N28K3_20mmB.jpg
#   inflating: /content/Datasets2/Fiber/N29R1_300mmB.jpg
#   inflating: /content/Datasets2/Fiber/N29R1_300mmB1.jpg
#   inflating: /content/Datasets2/Fiber/N2C1.1_300mmW.jpg
#   inflating: /content/Datasets2/Fiber/N2C1.1_300mmW1.jpg
#   inflating: /content/Datasets2/Fiber/N2C1.1_300mmW2.jpg
#   inflating: /content/Datasets2/Fiber/N2C3.2_20mmR.jpg
#   inflating: /content/Datasets2/Fiber/N2C3.2_20mmR1.jpg
#   inflating: /content/Datasets2/Fiber/N2C3.2_20mmR2.jpg
#   inflating: /content/Datasets2/Fiber/N2C3.2_300mmB.jpg
#   inflating: /content/Datasets2/Fiber/N2C3.2_300mmB1.jpg
#   inflating: /content/Datasets2/Fiber/N2K1_300mmB.jpg
#   inflating: /content/Datasets2/Fiber/N2K1_300mmB2.jpg
#   inflating: /content/Datasets2/Fiber/N2K3_300mmB.jpg
#   inflating: /content/Datasets2/Fiber/N2K3_300mmB1.jpg
#   inflating: /content/Datasets2/Fiber/N2K3_300mmB2.jpg
#   inflating: /content/Datasets2/Fiber/N2K3_300mmB3.jpg
#   inflating: /content/Datasets2/Fiber/N2M1.1_20mmR1.jpg
#   inflating: /content/Datasets2/Fiber/N2M1.1_20mmR2.jpg
#   inflating: /content/Datasets2/Fiber/N2M2.3_20mmB.jpg
#   inflating: /content/Datasets2/Fiber/N2M2.3_20mmB1.jpg
#   inflating: /content/Datasets2/Fiber/N2M2.3_20mmB2.jpg
#   inflating: /content/Datasets2/Fiber/N2P1.3_300mm1Y.jpg
#   inflating: /content/Datasets2/Fiber/N2P1.3_300mm2Y.jpg
#   inflating: /content/Datasets2/Fiber/N2P1.3_300mm3Y.jpg
#   inflating: /content/Datasets2/Fiber/N2P1.3_300mmY.jpg
#   inflating: /content/Datasets2/Fiber/N2P1_20mmB1.jpg
#   inflating: /content/Datasets2/Fiber/N2P1_20mmB2.jpg
#   inflating: /content/Datasets2/Fiber/N2P3.3_300mm2B.jpg
#   inflating: /content/Datasets2/Fiber/N2P3.3_300mm3B.jpg
#   inflating: /content/Datasets2/Fiber/N2P3.3_300mmB.jpg
#   inflating: /content/Datasets2/Fiber/N2R1.3_20mmR.jpg
#   inflating: /content/Datasets2/Fiber/N2R1.3_20mmR1.jpg
#   inflating: /content/Datasets2/Fiber/N2R1.3_20mmR2.jpg
#   inflating: /content/Datasets2/Fiber/N2R1_20mmB.jpg
#   inflating: /content/Datasets2/Fiber/N2R1_20mmB1.jpg
#   inflating: /content/Datasets2/Fiber/N2R1_20mmB2.jpg
#   inflating: /content/Datasets2/Fiber/N2T1.3_20mm2DB - Copy.jpg
#   inflating: /content/Datasets2/Fiber/N2T1P2.1_300mm1B.jpg
#   inflating: /content/Datasets2/Fiber/N2T1P2.1_300mmB.jpg
#   inflating: /content/Datasets2/Fiber/N3.1C2_300mmB.jpg
#   inflating: /content/Datasets2/Fiber/N3.1M1.3_20mmB2.jpg
#   inflating: /content/Datasets2/Fiber/N3.1M1.3_20mmB3.jpg
#   inflating: /content/Datasets2/Fiber/N35K3_20mmR.jpg
#   inflating: /content/Datasets2/Fiber/N35K3_20mmR2.jpg
#   inflating: /content/Datasets2/Fiber/N38K3_20mmDB.jpg
#   inflating: /content/Datasets2/Fiber/N38K3_20mmDB1.jpg
#   inflating: /content/Datasets2/Fiber/N38K3_20mmDB2.jpg
#   inflating: /content/Datasets2/Fiber/N39K3_20mmB.jpg
#   inflating: /content/Datasets2/Fiber/N39K3_20mmB2.jpg
#   inflating: /content/Datasets2/Fiber/N3C1_300mmB.jpg
#   inflating: /content/Datasets2/Fiber/N3C2_300mmB.jpg
#   inflating: /content/Datasets2/Fiber/N3C2_300mmB3.jpg
#   inflating: /content/Datasets2/Fiber/N3C2_300mmB4.jpg
#   inflating: /content/Datasets2/Fiber/N3K1_300mmB1 - Copy.jpg
#   inflating: /content/Datasets2/Fiber/N3K1_300mmB2 - Copy.jpg
#   inflating: /content/Datasets2/Fiber/N3K3_20mmW_T1.jpg
#   inflating: /content/Datasets2/Fiber/N3K3_20mmW_T2.jpg
#   inflating: /content/Datasets2/Fiber/N3M1.3_20mmB.jpg
#   inflating: /content/Datasets2/Fiber/N3M1.3_20mmB1.jpg
#   inflating: /content/Datasets2/Fiber/N3M2.2_20mmB.jpg
#   inflating: /content/Datasets2/Fiber/N3M2.2_20mmB1.jpg
#   inflating: /content/Datasets2/Fiber/N3M2.2_20mmB2.jpg
#   inflating: /content/Datasets2/Fiber/N3M2.3_20mmB.jpg
#   inflating: /content/Datasets2/Fiber/N3M2.3_20mmB1.jpg
#   inflating: /content/Datasets2/Fiber/N3M2.3_20mmB2.jpg
#   inflating: /content/Datasets2/Fiber/N3P1.2_20mm1DB.jpg
#   inflating: /content/Datasets2/Fiber/N3P1.2_20mm1W.jpg
#   inflating: /content/Datasets2/Fiber/N3P1.2_20mm2DB.jpg
#   inflating: /content/Datasets2/Fiber/N3P1.2_20mm2W.jpg
#   inflating: /content/Datasets2/Fiber/N3P1.2_20mmDB.jpg
#   inflating: /content/Datasets2/Fiber/N3P1.2_20mmW.jpg
#   inflating: /content/Datasets2/Fiber/N3P2_20mmB.jpg
#   inflating: /content/Datasets2/Fiber/N3P2_20mmB1.jpg
#   inflating: /content/Datasets2/Fiber/N3P2_20mmB2.jpg
#   inflating: /content/Datasets2/Fiber/N3P3.1_20mm2W.jpg
#   inflating: /content/Datasets2/Fiber/N3P3.1_20mm3W.jpg
#   inflating: /content/Datasets2/Fiber/N3P3.1_20mmW.jpg
#   inflating: /content/Datasets2/Fiber/N3P3.2_300mm1DB.jpg
#   inflating: /content/Datasets2/Fiber/N3P3.2_300mm2DB.jpg
#   inflating: /content/Datasets2/Fiber/N3P3.2_300mmDB.jpg
#   inflating: /content/Datasets2/Fiber/N3P3.3_300mm1B.jpg
#   inflating: /content/Datasets2/Fiber/N3P3.3_300mm2B.jpg
#   inflating: /content/Datasets2/Fiber/N3P3.3_300mmB.jpg
#   inflating: /content/Datasets2/Fiber/N3R1.3_20mmR.jpg
#   inflating: /content/Datasets2/Fiber/N3R1.3_20mmR2.jpg
#   inflating: /content/Datasets2/Fiber/N3R3_20mmR1.jpg
#   inflating: /content/Datasets2/Fiber/N3R3_300mmB.jpg
#   inflating: /content/Datasets2/Fiber/N3R3_300mmB1.jpg
#   inflating: /content/Datasets2/Fiber/N3R3_300mmB2.jpg
#   inflating: /content/Datasets2/Fiber/N3T1.1_300mm1B - Copy.jpg
#   inflating: /content/Datasets2/Fiber/N3T1P2.2_300mm.jpg
#   inflating: /content/Datasets2/Fiber/N3T1P2.2_300mm1B.jpg
#   inflating: /content/Datasets2/Fiber/N3T1_200mmDB.jpg
#   inflating: /content/Datasets2/Fiber/N3T1_200mmDB1.jpg
#   inflating: /content/Datasets2/Fiber/N3T1_200mmDB2.jpg
#   inflating: /content/Datasets2/Fiber/N3T3.1_300mm1B.jpg
#   inflating: /content/Datasets2/Fiber/N3T3.1_300mm2B.jpg
#   inflating: /content/Datasets2/Fiber/N3T3.1_300mmB.jpg
#   inflating: /content/Datasets2/Fiber/N4-5R1_300mmW_B.jpg
#   inflating: /content/Datasets2/Fiber/N4-5R1_300mmW_B2.jpg
#   inflating: /content/Datasets2/Fiber/N4-5T1_200mmDB.jpg
#   inflating: /content/Datasets2/Fiber/N4-5T1_200mmDB1.jpg
#   inflating: /content/Datasets2/Fiber/N4-5T1_200mmDB2.jpg
#   inflating: /content/Datasets2/Fiber/N4.1T1.3_20mm1R - Copy.jpg
#   inflating: /content/Datasets2/Fiber/N4.1T1.3_20mm2R - Copy.jpg
#   inflating: /content/Datasets2/Fiber/N4.1T1.3_20mmR - Copy.jpg
#   inflating: /content/Datasets2/Fiber/N4.1T1_300mmB.jpg
#   inflating: /content/Datasets2/Fiber/N4.1T1_300mmB1.jpg
#   inflating: /content/Datasets2/Fiber/N4.1T1_300mmB2.jpg
#   inflating: /content/Datasets2/Fiber/N40C3_300mmB.jpg
#   inflating: /content/Datasets2/Fiber/N42C3_300mmB2.jpg
#   inflating: /content/Datasets2/Fiber/N42C3_300mmB3.jpg
#   inflating: /content/Datasets2/Fiber/N46C1_20mmDB.jpg
#   inflating: /content/Datasets2/Fiber/N4K3_20mmBr.jpg
#   inflating: /content/Datasets2/Fiber/N4K3_20mmBr1.jpg
#   inflating: /content/Datasets2/Fiber/N4K3_20mmBr2.jpg
#   inflating: /content/Datasets2/Fiber/N4P1.2_20mm1W.jpg
#   inflating: /content/Datasets2/Fiber/N4P2.3_20mm1B.jpg
#   inflating: /content/Datasets2/Fiber/N4P2.3_20mmB.jpg
#   inflating: /content/Datasets2/Fiber/N4P2.3_300mm1DB.jpg
#   inflating: /content/Datasets2/Fiber/N4P2.3_300mm2DB.jpg
#   inflating: /content/Datasets2/Fiber/N4P2.3_300mm3DB.jpg
#   inflating: /content/Datasets2/Fiber/N4P2.3_300mm4DB.jpg
#   inflating: /content/Datasets2/Fiber/N4P2.3_300mm5DB.jpg
#   inflating: /content/Datasets2/Fiber/N4P3.1_20mm1W.jpg
#   inflating: /content/Datasets2/Fiber/N4P3.1_20mm2DB.jpg
#   inflating: /content/Datasets2/Fiber/N4P3.2_300mm1B.jpg
#   inflating: /content/Datasets2/Fiber/N4P3.2_300mm2B.jpg
#   inflating: /content/Datasets2/Fiber/N4P3.2_300mm3B.jpg
#   inflating: /content/Datasets2/Fiber/N4P3.2_300mmB.jpg
#   inflating: /content/Datasets2/Fiber/N4R1.2_20mmB.jpg
#   inflating: /content/Datasets2/Fiber/N4R1.2_20mmB1.jpg
#   inflating: /content/Datasets2/Fiber/N4R1.2_20mmB2.jpg
#   inflating: /content/Datasets2/Fiber/N4R1.3_20mmBr1.jpg
#   inflating: /content/Datasets2/Fiber/N4R2.1_20mmB.jpg
#   inflating: /content/Datasets2/Fiber/N4R2.1_20mmB1.jpg
#   inflating: /content/Datasets2/Fiber/N4R2.1_20mmB2.jpg
#   inflating: /content/Datasets2/Fiber/N4T1.3_20mm1R - Copy.jpg
#   inflating: /content/Datasets2/Fiber/N4T1.3_20mm2R - Copy.jpg
#   inflating: /content/Datasets2/Fiber/N4T1.3_20mmR - Copy.jpg
#   inflating: /content/Datasets2/Fiber/N4T1_300mmB.jpg
#   inflating: /content/Datasets2/Fiber/N4T1_300mmB1.jpg
#   inflating: /content/Datasets2/Fiber/N4T1_300mmB2.jpg
#   inflating: /content/Datasets2/Fiber/N4T2.2_20mm1B - Copy.jpg
#   inflating: /content/Datasets2/Fiber/N4T2.2_20mmB - Copy.jpg
#   inflating: /content/Datasets2/Fiber/N4T2.2_20mmDB - Copy.jpg
#   inflating: /content/Datasets2/Fiber/N4T2.3_300mmB - Copy.jpg
#   inflating: /content/Datasets2/Fiber/N4T3_300mmB (3).jpg
#   inflating: /content/Datasets2/Fiber/N4T3_300mmB (3)1.jpg
#   inflating: /content/Datasets2/Fiber/N4T3_300mmB (3)2.jpg
#   inflating: /content/Datasets2/Fiber/N5.1M2.2_20mmW.jpg
#   inflating: /content/Datasets2/Fiber/N5.1M2.2_20mmW1.jpg
#   inflating: /content/Datasets2/Fiber/N5.1M2.2_20mmW2.jpg
#   inflating: /content/Datasets2/Fiber/N5.1P1.1_20mm1W.jpg
#   inflating: /content/Datasets2/Fiber/N5.1P1.1_20mm2W.jpg
#   inflating: /content/Datasets2/Fiber/N5.1P1.1_20mmW.jpg
#   inflating: /content/Datasets2/Fiber/N5.1P3.2_20mm1R.jpg
#   inflating: /content/Datasets2/Fiber/N5.1P3.2_20mm2R.jpg
#   inflating: /content/Datasets2/Fiber/N5.1P3.2_20mm3R.jpg
#   inflating: /content/Datasets2/Fiber/N5.1P3.2_20mmR.jpg
#   inflating: /content/Datasets2/Fiber/N5.2M2.2_20mmW.jpg
#   inflating: /content/Datasets2/Fiber/N5.2M2.2_20mmW1.jpg
#   inflating: /content/Datasets2/Fiber/N5.2M2.2_20mmW2.jpg
#   inflating: /content/Datasets2/Fiber/N5.2P1.1_20mm1W.jpg
#   inflating: /content/Datasets2/Fiber/N5.2P1.1_20mm2W.jpg
#   inflating: /content/Datasets2/Fiber/N5.2P1.1_20mmW.jpg
#   inflating: /content/Datasets2/Fiber/N5.2P3.2_20mm1R.jpg
#   inflating: /content/Datasets2/Fiber/N5.2T1P2.1_300mmB.jpg
#   inflating: /content/Datasets2/Fiber/N5.3M2.2_20mmW.jpg
#   inflating: /content/Datasets2/Fiber/N5.3M2.2_20mmW1.jpg
#   inflating: /content/Datasets2/Fiber/N5.3M2.2_20mmW2.jpg
#   inflating: /content/Datasets2/Fiber/N5.3P1.1_20mm1W.jpg
#   inflating: /content/Datasets2/Fiber/N5.3P1.1_20mm2W.jpg
#   inflating: /content/Datasets2/Fiber/N5.3P1.1_20mmW.jpg
#   inflating: /content/Datasets2/Fiber/N5.4M2.2_20mmW.jpg
#   inflating: /content/Datasets2/Fiber/N5.4M2.2_20mmW1.jpg
#   inflating: /content/Datasets2/Fiber/N5.4M2.2_20mmW2.jpg
#   inflating: /content/Datasets2/Fiber/N5.5T1P2.1_300mmB.jpg
#   inflating: /content/Datasets2/Fiber/N5.jpg
#   inflating: /content/Datasets2/Fiber/N56.1C3_300mmB.jpg
#   inflating: /content/Datasets2/Fiber/N56.1C3_300mmB2.jpg
#   inflating: /content/Datasets2/Fiber/N56.2C3_300mmB.jpg
#   inflating: /content/Datasets2/Fiber/N56.2C3_300mmB2.jpg
#   inflating: /content/Datasets2/Fiber/N56C3_300mmB.jpg
#   inflating: /content/Datasets2/Fiber/N56C3_300mmB2.jpg
#   inflating: /content/Datasets2/Fiber/N59C3_300mmB.jpg
#   inflating: /content/Datasets2/Fiber/N59C3_300mmB1 - Copy.jpg
#   inflating: /content/Datasets2/Fiber/N59C3_300mmB1.jpg
#   inflating: /content/Datasets2/Fiber/N59C3_300mmB2.jpg
#   inflating: /content/Datasets2/Fiber/N5C1.2_20mmR.jpg
#   inflating: /content/Datasets2/Fiber/N5C1.2_20mmR1.jpg
#   inflating: /content/Datasets2/Fiber/N5C1.2_20mmR2.jpg
#   inflating: /content/Datasets2/Fiber/N5C2_20mmDB.jpg
#   inflating: /content/Datasets2/Fiber/N5C2_20mmDB1.jpg
#   inflating: /content/Datasets2/Fiber/N5K1_300mmB.jpg
#   inflating: /content/Datasets2/Fiber/N5K2_20mmB.jpg
#   inflating: /content/Datasets2/Fiber/N5K2_20mmB1.jpg
#   inflating: /content/Datasets2/Fiber/N5K2_20mmB2.jpg
#   inflating: /content/Datasets2/Fiber/N5K3_20mmB.jpg
#   inflating: /content/Datasets2/Fiber/N5K3_20mmB1.jpg
#   inflating: /content/Datasets2/Fiber/N5K3_20mmB2.jpg
#   inflating: /content/Datasets2/Fiber/N5M2.2_20mmW.jpg
#   inflating: /content/Datasets2/Fiber/N5M2.2_20mmW1.jpg
#   inflating: /content/Datasets2/Fiber/N5M2.2_20mmW2.jpg
#   inflating: /content/Datasets2/Fiber/N5P1.1_20mm1W.jpg
#   inflating: /content/Datasets2/Fiber/N5P1.1_20mm2W.jpg
#   inflating: /content/Datasets2/Fiber/N5P1.1_20mmW.jpg
#   inflating: /content/Datasets2/Fiber/N5P1.3_300mm1DB.jpg
#   inflating: /content/Datasets2/Fiber/N5P1.3_300mm2DB.jpg
#   inflating: /content/Datasets2/Fiber/N5P1.3_300mmDB.jpg
#   inflating: /content/Datasets2/Fiber/N5P2.3_20mmR.jpg
#   inflating: /content/Datasets2/Fiber/N5P2_300mmB.jpg
#   inflating: /content/Datasets2/Fiber/N5P2_300mmB1.jpg
#   inflating: /content/Datasets2/Fiber/N5P2_300mmB2.jpg
#   inflating: /content/Datasets2/Fiber/N5T1.1_20mm1B - Copy.jpg
#   inflating: /content/Datasets2/Fiber/N5T1.1_20mm2B - Copy.jpg
#   inflating: /content/Datasets2/Fiber/N5T1.1_20mmB - Copy.jpg
#   inflating: /content/Datasets2/Fiber/N5T1.2_20mm2B - Copy.jpg
#   inflating: /content/Datasets2/Fiber/N5T1.2_20mmB - Copy.jpg
#   inflating: /content/Datasets2/Fiber/N5T1.3_20mm1DB - Copy.jpg
#   inflating: /content/Datasets2/Fiber/N5T1.3_20mm2DB - Copy.jpg
#   inflating: /content/Datasets2/Fiber/N5T1.3_20mmDB - Copy.jpg
#   inflating: /content/Datasets2/Fiber/N5T1.3_300mm1B - Copy.jpg
#   inflating: /content/Datasets2/Fiber/N5T1.3_300mm2B - Copy.jpg
#   inflating: /content/Datasets2/Fiber/N5T1.3_300mm3B - Copy.jpg
#   inflating: /content/Datasets2/Fiber/N5T1.3_300mmB - Copy.jpg
#   inflating: /content/Datasets2/Fiber/N6.1K1_300mmB.jpg
#   inflating: /content/Datasets2/Fiber/N6.1K1_300mmB2.jpg
#   inflating: /content/Datasets2/Fiber/N6.3K1_300mmB.jpg
#   inflating: /content/Datasets2/Fiber/N6.4K1_300mmB.jpg
#   inflating: /content/Datasets2/Fiber/N6.4K1_300mmB2.jpg
#   inflating: /content/Datasets2/Fiber/N6C2_300mmB1.jpg
#   inflating: /content/Datasets2/Fiber/N6P1.2_20mm1W.jpg
#   inflating: /content/Datasets2/Fiber/N6P1.2_20mm2W.jpg
#   inflating: /content/Datasets2/Fiber/N6P1.2_20mmW.jpg
#   inflating: /content/Datasets2/Fiber/N6P1_20mmR.jpg
#   inflating: /content/Datasets2/Fiber/N6P1_20mmR2.jpg
#   inflating: /content/Datasets2/Fiber/N6P2.3_20mm1DB.jpg
#   inflating: /content/Datasets2/Fiber/N6P2.3_20mm2DB.jpg
#   inflating: /content/Datasets2/Fiber/N6P2.3_20mm3DB.jpg
#   inflating: /content/Datasets2/Fiber/N6P2.3_20mmDB.jpg
#   inflating: /content/Datasets2/Fiber/N6P2_20mmR.jpg
#   inflating: /content/Datasets2/Fiber/N6P2_20mmR1.jpg
#   inflating: /content/Datasets2/Fiber/N6P2_20mmR2.jpg
#   inflating: /content/Datasets2/Fiber/N6T1_200mmDB.jpg
#   inflating: /content/Datasets2/Fiber/N6T1_200mmDB1.jpg
#   inflating: /content/Datasets2/Fiber/N6T1_200mmDB2.jpg
#   inflating: /content/Datasets2/Fiber/N7P1.2_20mm1W.jpg
#   inflating: /content/Datasets2/Fiber/N7P1.2_20mm2W.jpg
#   inflating: /content/Datasets2/Fiber/N7P1.2_20mmW.jpg
#   inflating: /content/Datasets2/Fiber/N7P1_20mmDB.jpg
#   inflating: /content/Datasets2/Fiber/N7P1_20mmDB1.jpg
#   inflating: /content/Datasets2/Fiber/N7P1_20mmDB2.jpg
#   inflating: /content/Datasets2/Fiber/N7P2_20mmB - Copy.jpg
#   inflating: /content/Datasets2/Fiber/N7P2_20mmB1 - Copy.jpg
#   inflating: /content/Datasets2/Fiber/N7P2_20mmB2 - Copy.jpg
#   inflating: /content/Datasets2/Fiber/N7T1_200mmW.jpg
#   inflating: /content/Datasets2/Fiber/N7T1_200mmW1.jpg
#   inflating: /content/Datasets2/Fiber/N7T1_200mmW2.jpg
#   inflating: /content/Datasets2/Fiber/N7T1_20mmB (2) - Copy.jpg
#   inflating: /content/Datasets2/Fiber/N7T1_20mmB1 (2) - Copy.jpg
# ...
#   inflating: /content/Datasets2/Fragment/N7T1_20mmB.jpg
#   inflating: /content/Datasets2/Fragment/N7T1_20mmB1.jpg
#   inflating: /content/Datasets2/Fragment/N7T1_20mmB2.jpg
#   inflating: /content/Datasets2/Fragment/N7T2_300mmB.jpg
#   inflating: /content/Datasets2/Fragment/N8-9R1.2_20mmR_B.jpg
#   inflating: /content/Datasets2/Fragment/N8-9R1.2_20mmR_B1.jpg
#   inflating: /content/Datasets2/Fragment/N8-9R1.2_20mmR_B2.jpg
#   inflating: /content/Datasets2/Fragment/N8R3_20mmDB1 (1).jpg
#   inflating: /content/Datasets2/Fragment/N9-10K3_20mmBr.jpg
#    creating: /content/Datasets2/Pellet/
#   inflating: /content/Datasets2/Pellet/AA_CW_1_212-500_110_jpg.rf.99812e28d914fb7cca9d7af67a3b4e33.jpg
#   inflating: /content/Datasets2/Pellet/AA_CW_1_above500_92_jpg.rf.54e8daf625f4df1b9732f48207cd9b9c.jpg
#   inflating: /content/Datasets2/Pellet/AA_CW_1_above500_92_jpg.rf.6b01acf22d3ac8a3eb0fad5f91c97863.jpg
#   inflating: /content/Datasets2/Pellet/AA_CW_1_above500_92_jpg.rf.a98f4775f236aa822aca79d6f616cdaf.jpg
#   inflating: /content/Datasets2/Pellet/AA_CW_2_212-500_15_jpg.rf.aa31950902b0159d8134ce1610d8882b.jpg
#   inflating: /content/Datasets2/Pellet/AA_CW_2_212-500_24_jpg.rf.303b30c19b7c43439ae7274205284bf8.jpg
#   inflating: /content/Datasets2/Pellet/AA_CW_2_212-500_24_jpg.rf.4c1514597b7568e7b8433a6d366df525.jpg
#   inflating: /content/Datasets2/Pellet/AA_CW_2_212-500_24_jpg.rf.855ab354c9d8b02352b1dcbcd44806b2.jpg
#   inflating: /content/Datasets2/Pellet/AA_CW_2_above500_30_jpg.rf.73b76202e2e1c6e531b413e76563a46d.jpg
#   inflating: /content/Datasets2/Pellet/AA_CW_3_212-500_153_jpg.rf.5e439b39d0410acd72bf363a9d74a39a.jpg
#   inflating: /content/Datasets2/Pellet/AA_DW_3_212-500_53_jpg.rf.42f4c891fe424fa12f66fa3841cec7dc.jpg
#   inflating: /content/Datasets2/Pellet/AA_DW_3_212-500_67_jpg.rf.4830a07784a51f3827b142dfb6d6466f.jpg
#   inflating: /content/Datasets2/Pellet/AA_DW_3_212-500_67_jpg.rf.68a60f8a0440836e7af5670b540c9869.jpg
#   inflating: /content/Datasets2/Pellet/AA_DW_3_212-500_67_jpg.rf.79937e7828644a3c1b9a55ba54cebe04.jpg
#   inflating: /content/Datasets2/Pellet/AA_DW_3_above500_135_jpg.rf.106f24e81abe89415d5f47a35406043c.jpg
#   inflating: /content/Datasets2/Pellet/AA_DW_3_above500_135_jpg.rf.4c3102f42c84ccdb4dc2bdef1eb5463c.jpg
#   inflating: /content/Datasets2/Pellet/AA_DW_3_above500_135_jpg.rf.bddf758a2c1e8606ec13263381c0cf37.jpg
#   inflating: /content/Datasets2/Pellet/AA_FT_1_above500_25_jpg.rf.c6ffda30cd34d01b2ec7874f007fcfa0.jpg
#   inflating: /content/Datasets2/Pellet/AA_FT_1_above500_46_jpg.rf.51b8d0982fcf5d377d86ebe78d0351a2.jpg
#   inflating: /content/Datasets2/Pellet/AA_FT_1_above500_46_jpg.rf.7f6783975b0175e5fd7a40fd35b2632b.jpg
#   inflating: /content/Datasets2/Pellet/AA_FT_1_above500_46_jpg.rf.f56565fd4c111c84570c39b438bd17d4.jpg
#   inflating: /content/Datasets2/Pellet/AA_FT_2_212-500_55_jpg.rf.aa10b0964f983cce6378aba857a4e3dc.jpg
#   inflating: /content/Datasets2/Pellet/AA_FT_2_212-500_56_jpg.rf.49b290eea00eb92fc6cd813e8cca8295.jpg
#   inflating: /content/Datasets2/Pellet/AA_FT_2_212-500_56_jpg.rf.531a842c1ec3cbbf47bed3482e2f902f.jpg
#   inflating: /content/Datasets2/Pellet/AA_FT_2_212-500_56_jpg.rf.710347b1195c8f2814ab653ff83cc032.jpg
#   inflating: /content/Datasets2/Pellet/AA_FT_3_20-212_88_jpg.rf.3e485cff863ebc3f2c3762f0fff72c6e.jpg
#   inflating: /content/Datasets2/Pellet/AA_FT_3_20-212_89_jpg.rf.8aba074f945f99afb02d87b6165d4760.jpg
#   inflating: /content/Datasets2/Pellet/AA_FT_3_above500_13_jpg.rf.45c89848cac2ccfcb0a4b26db3af9375.jpg
#   inflating: /content/Datasets2/Pellet/AA_FT_3_above500_7_jpg.rf.267db1d7ecb122c20bbc98134afbed83.jpg
#   inflating: /content/Datasets2/Pellet/AA_FT_3_above500_7_jpg.rf.46e675008e1444155cd018479f9018cb.jpg
#   inflating: /content/Datasets2/Pellet/AA_FT_3_above500_7_jpg.rf.d3147db6519dac0b77ea88d6bd277a5d.jpg
#   inflating: /content/Datasets2/Pellet/AA_SD_1_above500_18_jpg.rf.df9c2ef10de25f54442c36380188e12e.jpg
#   inflating: /content/Datasets2/Pellet/AA_SD_2_20-212_87_jpg.rf.125de4be1a192926ad3c765a10aa5bce.jpg
#   inflating: /content/Datasets2/Pellet/AA_SD_2_20-212_87_jpg.rf.585e2b5a6fa21a521aca5795a793dae2.jpg
#   inflating: /content/Datasets2/Pellet/AA_SD_2_20-212_87_jpg.rf.588d4fdf07625bd92e44859667eda67f.jpg
#   inflating: /content/Datasets2/Pellet/AA_SD_2_20-212_90_jpg.rf.4771d48089d3f971951c9e44fa4d2062.jpg
#   inflating: /content/Datasets2/Pellet/AA_SD_2_20-212_90_jpg.rf.8f2bbf0c9a01d6b609fdfb68881c799b.jpg
#   inflating: /content/Datasets2/Pellet/AA_SD_2_20-212_90_jpg.rf.97c6a3993533a9a03d21c67bd262d2da.jpg
#   inflating: /content/Datasets2/Pellet/AA_SD_2_20-212_94_jpg.rf.56ba6a1460eeb65d251d19472d2a54f4.jpg
#   inflating: /content/Datasets2/Pellet/AA_SD_2_above500_20_jpg.rf.2a87ed393b168de5b6567de7231a327d.jpg
#   inflating: /content/Datasets2/Pellet/AA_SD_2_above500_20_jpg.rf.82599585ff309d06191f4348bc47d6d1.jpg
#   inflating: /content/Datasets2/Pellet/AA_SD_2_above500_20_jpg.rf.e988710efa425d08daba49fb45649e2c.jpg
#   inflating: /content/Datasets2/Pellet/AA_SD_3_above500_21_jpg.rf.694125e055b7d4780903e476382c265a.jpg
#   inflating: /content/Datasets2/Pellet/ALGALITA_CW_1_212-500_756_jpg.rf.5e4018eeb7a515823538befdeba0e2e3.jpg
#   inflating: /content/Datasets2/Pellet/ALGALITA_CW_1_212-500_756_jpg.rf.814f4315e4f94348dea62abfb3331ab4.jpg
#   inflating: /content/Datasets2/Pellet/ALGALITA_CW_1_212-500_756_jpg.rf.e4e411c76a5cae81719a4f9e0f2d3d83.jpg
#   inflating: /content/Datasets2/Pellet/ALGALITA_CW_2_above500_27_jpg.rf.6808cd73ac309f74236494d3fad7bc3b.jpg
#   inflating: /content/Datasets2/Pellet/ALGALITA_CW_2_above500_27_jpg.rf.773e60ef30c753752d466531d3b5e132.jpg
#   inflating: /content/Datasets2/Pellet/ALGALITA_CW_2_above500_27_jpg.rf.914f9a2c7470ba6e5d7c70c18bddeaa2.jpg
#   inflating: /content/Datasets2/Pellet/ALGALITA_CW_3_20-212_109_jpg.rf.143c9ed0311ca8aa249d2e0f3a25110f.jpg
#   inflating: /content/Datasets2/Pellet/ALGALITA_CW_3_20-212_109_jpg.rf.b83157625c86b4b70261492e8a631c82.jpg
#   inflating: /content/Datasets2/Pellet/ALGALITA_CW_3_20-212_109_jpg.rf.fbbdcd89fd8f32f2228cb52caeea095c.jpg
#   inflating: /content/Datasets2/Pellet/B_CW_1_212-500_101_jpg.rf.019a9c82dac09b4c860be11d71465fbf.jpg
#   inflating: /content/Datasets2/Pellet/B_CW_1_212-500_101_jpg.rf.9168289b92f2ed705e911fa33349ae38.jpg
#   inflating: /content/Datasets2/Pellet/B_CW_1_212-500_101_jpg.rf.fd0ca639ad6af1c584873d2d3c712d74.jpg
#   inflating: /content/Datasets2/Pellet/B_CW_1_212-500_108_jpg.rf.499ac2deef2b67c1ea0d18c490b5d39d.jpg
#   inflating: /content/Datasets2/Pellet/B_CW_1_212-500_108_jpg.rf.567f4acf84a51a2cb99035523bfcadfc.jpg
#   inflating: /content/Datasets2/Pellet/B_CW_1_212-500_108_jpg.rf.b63e9b7fccc9137502ca2319ddc7d7e8.jpg
#   inflating: /content/Datasets2/Pellet/B_CW_1_above500_16_jpg.rf.a78ac982419a48ccdb00b28e805f8cb2.jpg
#   inflating: /content/Datasets2/Pellet/B_CW_1_above500_16_jpg.rf.b9af1ef592cb9bfca2580556242adaa5.jpg
#   inflating: /content/Datasets2/Pellet/B_CW_1_above500_16_jpg.rf.c8b87b9d6be8b8bdf7e7665a6fe9a167.jpg
#   inflating: /content/Datasets2/Pellet/B_CW_1_above500_17_jpg.rf.49753d49305706feb9a30b16e3650c3b.jpg
#   inflating: /content/Datasets2/Pellet/B_CW_1_above500_17_jpg.rf.4ed2e2951b5dc57ee49368c6d9d2cd0e.jpg
#   inflating: /content/Datasets2/Pellet/B_CW_1_above500_17_jpg.rf.e76ac64a66dd1bc294a4544844b9892f.jpg
#   inflating: /content/Datasets2/Pellet/B_CW_1_above500_2_jpg.rf.5d06a9613ec4c6d2445df1bab3a92c46.jpg
#   inflating: /content/Datasets2/Pellet/B_CW_1_above500_2_jpg.rf.924bf098f747485f71b0d1658ebe198a.jpg
#   inflating: /content/Datasets2/Pellet/B_CW_1_above500_2_jpg.rf.92f610dc1174109dd13f76025b1e84f7.jpg
#   inflating: /content/Datasets2/Pellet/B_CW_2_above500_8_jpg.rf.194cd08690f2808f4a96e83cf56a9a25.jpg
#   inflating: /content/Datasets2/Pellet/B_CW_2_above500_8_jpg.rf.23b1607dc32a9ff4657f9a468392a04f.jpg
#   inflating: /content/Datasets2/Pellet/B_CW_2_above500_8_jpg.rf.dbdf883aef332eb590f8959ea62f675e.jpg
#   inflating: /content/Datasets2/Pellet/B_CW_2_above500_9_jpg.rf.18562e43ab396c7911fa69ed23869998.jpg
#   inflating: /content/Datasets2/Pellet/B_CW_2_above500_9_jpg.rf.d91020ce43ba2a219b199525580ebb08.jpg
#   inflating: /content/Datasets2/Pellet/B_CW_3_212-500_35_jpg.rf.18c8973470224079c6098619802812b5.jpg
#   inflating: /content/Datasets2/Pellet/B_CW_3_212-500_35_jpg.rf.617b45f553889a192b99ca7d6fd912e7.jpg
#   inflating: /content/Datasets2/Pellet/B_CW_3_212-500_35_jpg.rf.6bd0f4de9c6f123d2f9d5220169e1134.jpg
#   inflating: /content/Datasets2/Pellet/B_DW_1_above500_19_jpg.rf.f3f4e93ca3421c1021bf935ecc33c473.jpg
#   inflating: /content/Datasets2/Pellet/B_DW_1_above500_66_jpg.rf.29e09019e667c6ebf22771399a6091be.jpg
#   inflating: /content/Datasets2/Pellet/B_DW_1_above500_66_jpg.rf.8a3266b557b70af2a9175caf8eb9c03b.jpg
#   inflating: /content/Datasets2/Pellet/B_DW_1_above500_66_jpg.rf.8d3f05b288a35c87cf7a0bd9a2dd71f9.jpg
#   inflating: /content/Datasets2/Pellet/B_DW_2_212-500_5_jpg.rf.643dab282e49ec2596152851a6b3e32e.jpg
#   inflating: /content/Datasets2/Pellet/B_DW_2_212-500_5_jpg.rf.8efd5de5645b4f7c4fe539630fea6812.jpg
#   inflating: /content/Datasets2/Pellet/B_DW_2_212-500_5_jpg.rf.ff3e2762d667929d2ec7f986c1110d56.jpg
#   inflating: /content/Datasets2/Pellet/B_DW_3_212-500_20_jpg.rf.49c6f1018066fbf235d357362c2c4ce2.jpg
#   inflating: /content/Datasets2/Pellet/B_DW_3_212-500_20_jpg.rf.96f8a1d7ac361927514f091bfe53e68d.jpg
#   inflating: /content/Datasets2/Pellet/B_DW_3_212-500_20_jpg.rf.b00d17f68d508253f404aca60a4522f5.jpg
#   inflating: /content/Datasets2/Pellet/CC_CW_2_20-250_217_jpg.rf.20e96b5b973e82b0f8cc2eea725e827c.jpg
#   inflating: /content/Datasets2/Pellet/CC_CW_2_20-250_217_jpg.rf.391d765c625ae20b7ac7689867dbae1d.jpg
#   inflating: /content/Datasets2/Pellet/CC_CW_2_20-250_217_jpg.rf.9d816bda9e795ffa31699a6bb43380f9.jpg
#   inflating: /content/Datasets2/Pellet/CC_CW_3_above500_155_jpg.rf.9a6050b26a6538102170f8d44705a8cb.jpg
#   inflating: /content/Datasets2/Pellet/CC_CW_3_above500_157_jpg.rf.26a91cb2c3a05e6b53680acef9ccd870.jpg
#   inflating: /content/Datasets2/Pellet/CC_FT_2_250-500_425_jpg.rf.4228c316f897bf1c8e045f26d66c0632.jpg
#   inflating: /content/Datasets2/Pellet/CC_FT_2_250-500_425_jpg.rf.9d4490c53e802e4ca35e4f144c76416d.jpg
#   inflating: /content/Datasets2/Pellet/CC_FT_2_250-500_425_jpg.rf.c2d83371bf420576866a3cc4558460e1.jpg
#   inflating: /content/Datasets2/Pellet/CC_FT_3_250-500_505_jpg.rf.b7c20873de13a83df3071283a4fd0432.jpg
#   inflating: /content/Datasets2/Pellet/CC_SD_1_above500_812_jpg.rf.05ab3e2bdee62c96a126012c1f597e0d.jpg
#   inflating: /content/Datasets2/Pellet/CC_SD_1_above500_812_jpg.rf.4ed7899bc15a8a2dac4bca9d1f4a1e19.jpg
#   inflating: /content/Datasets2/Pellet/CC_SD_1_above500_812_jpg.rf.a7a9a94b681059518b69caced65cf81b.jpg
#   inflating: /content/Datasets2/Pellet/CC_SD_2_above500_702_jpg.rf.34e40c57258869fb729a8af45cecc1f5.jpg
#   inflating: /content/Datasets2/Pellet/CC_SD_2_above500_702_jpg.rf.73ac1dfff0ec0fa4ebdec7a9976290b6.jpg
#   inflating: /content/Datasets2/Pellet/CC_SD_2_above500_702_jpg.rf.d70803d6bf8f1a0ea7812e3efae305b8.jpg
#   inflating: /content/Datasets2/Pellet/CC_SD_3_250-500_763_jpg.rf.edfce456b2f646639203ab71937d07c0.jpg
#   inflating: /content/Datasets2/Pellet/C_CW_1_212-500_39_jpg.rf.b0d02a4095f8d923c747212be1e82140.jpg
#   inflating: /content/Datasets2/Pellet/C_CW_1_212-500_39_jpg.rf.b371fda05b5c24a30862bec7059f6f50.jpg
#   inflating: /content/Datasets2/Pellet/C_CW_1_212-500_39_jpg.rf.c1059086ddd41ef38dc61189c20f614a.jpg
#   inflating: /content/Datasets2/Pellet/C_CW_1_212-500_40_jpg.rf.993843d3e61cd624f8bd38be0548d13c.jpg
#   inflating: /content/Datasets2/Pellet/C_CW_1_above500_3_jpg.rf.9cdc0a2def137c832f7d43334185c84c.jpg
#   inflating: /content/Datasets2/Pellet/C_CW_2_above500_8_jpg.rf.1ea2f3239334f22b231bdad5cf5c853c.jpg
#   inflating: /content/Datasets2/Pellet/C_CW_2_above500_8_jpg.rf.35e9a9a069a88f19848caf3eb208698f.jpg
#   inflating: /content/Datasets2/Pellet/C_CW_2_above500_8_jpg.rf.a508094ef6409b11e2f4621510879d21.jpg
#   inflating: /content/Datasets2/Pellet/C_CW_3_212-500_75_jpg.rf.1538a0df01c5768de489a6480bc5a08c.jpg
#   inflating: /content/Datasets2/Pellet/C_CW_3_212-500_75_jpg.rf.732bab65718999ed171014851f65bf6d.jpg
#   inflating: /content/Datasets2/Pellet/C_CW_3_212-500_75_jpg.rf.b35780129b100a7da76c9318745c2865.jpg
#   inflating: /content/Datasets2/Pellet/C_CW_3_above500_8_jpg.rf.305f90283d20a8dd89763420609004f7.jpg
#   inflating: /content/Datasets2/Pellet/C_DW_1_212-500_3_jpg.rf.06875ed739c14da2e9ff3f622a6db7c6.jpg
#   inflating: /content/Datasets2/Pellet/C_DW_1_212-500_3_jpg.rf.275b53d803af12410c68e9bdfb53daa2.jpg
#   inflating: /content/Datasets2/Pellet/C_DW_1_212-500_3_jpg.rf.41011e158651ba46f769ab661557aa6c.jpg
#   inflating: /content/Datasets2/Pellet/C_DW_1_212-500_5_jpg.rf.791ffee090fc3634d3a43ecb364088db.jpg
#   inflating: /content/Datasets2/Pellet/C_DW_1_212-500_5_jpg.rf.a818fbda7d78f4f46ebeecc00485041e.jpg
#   inflating: /content/Datasets2/Pellet/C_DW_1_212-500_5_jpg.rf.f83c501b89f2f77cca2be1bf7dfed04d.jpg
#   inflating: /content/Datasets2/Pellet/C_DW_1_212-500_9_jpg.rf.34400d83786b295afec240e83dad3c24.jpg
#   inflating: /content/Datasets2/Pellet/C_DW_1_212-500_9_jpg.rf.9b85ac885f4e0e2a8ae66e175de61760.jpg
#   inflating: /content/Datasets2/Pellet/C_DW_1_212-500_9_jpg.rf.dffc35353617ce65fc29acc5953c5d0d.jpg
#   inflating: /content/Datasets2/Pellet/C_DW_3_above500_21_jpg.rf.6b0abef79bad7da1af8c8fe9d7623b63.jpg
#   inflating: /content/Datasets2/Pellet/C_DW_3_above500_21_jpg.rf.8b6762af22601b54f015b5ca8cc2c941.jpg
#   inflating: /content/Datasets2/Pellet/C_DW_3_above500_21_jpg.rf.c0991d1ef32ed7ad1aa5fe36aee78a36.jpg
#   inflating: /content/Datasets2/Pellet/DD_CW_3_Stereoscope_212-500_23_jpg.rf.db545801dd3dce5e3aa5f3877823d2c1.jpg
#   inflating: /content/Datasets2/Pellet/DD_CW_3_Stereoscope_212-500_5_jpg.rf.87485e487008d2284b95b4534034a332.jpg
#   inflating: /content/Datasets2/Pellet/D_SD_1_above500_10_jpg.rf.e4163cd78111106a221220f45dfa0dd3.jpg
#   inflating: /content/Datasets2/Pellet/D_SD_1_above500_20_jpg.rf.08828b3c37dafc1e2170f7b6e7a0ffe7.jpg
#   inflating: /content/Datasets2/Pellet/H_CW_1_212-500_22_jpg.rf.74e40ad747f33229894f9665a14609cc.jpg
#   inflating: /content/Datasets2/Pellet/H_CW_1_212-500_22_jpg.rf.bde71d4a106b8384d2580e2c4db3f795.jpg
#   inflating: /content/Datasets2/Pellet/H_CW_1_212-500_22_jpg.rf.f599ca169f6ac71ce581c66d330dfd26.jpg
#   inflating: /content/Datasets2/Pellet/H_CW_1_212-500_66_jpg.rf.216da1b17575787ae2046be909276b05.jpg
#   inflating: /content/Datasets2/Pellet/H_CW_1_212-500_66_jpg.rf.82a20ead4f2d073e60d215b6c13b0834.jpg
#   inflating: /content/Datasets2/Pellet/H_CW_1_212-500_66_jpg.rf.b454ac15642fce02f2a2f91786632c19.jpg
#   inflating: /content/Datasets2/Pellet/H_CW_2_above500_119_jpg.rf.11d9cf386a568425dc743ffb72c9b3b9.jpg
#   inflating: /content/Datasets2/Pellet/H_CW_2_above500_119_jpg.rf.87be9876c19eff4e574b3c38d1100ae6.jpg
#   inflating: /content/Datasets2/Pellet/H_CW_2_above500_119_jpg.rf.af58797efb88256195021173313b8380.jpg
#   inflating: /content/Datasets2/Pellet/JJ_CW_1_above500_22_jpg.rf.276e3ba6a7f1062229c9699cb20aecb5.jpg
#   inflating: /content/Datasets2/Pellet/JJ_CW_1_above500_22_jpg.rf.3267f378f8640482b9faaa56a5a21c86.jpg
#   inflating: /content/Datasets2/Pellet/JJ_CW_1_above500_22_jpg.rf.81f2ab209fee1672bf2b8f2f570dd7e3.jpg
#   inflating: /content/Datasets2/Pellet/JJ_CW_3_above500_17_jpg.rf.8ddbd07919d54c211fa4750cfdcbc4b5.jpg
#   inflating: /content/Datasets2/Pellet/JJ_CW_3_above500_5_jpg.rf.062508ff6574459458cb0eacb802ec10.jpg
#   inflating: /content/Datasets2/Pellet/JJ_CW_3_above500_5_jpg.rf.4596cfae99a2c5351ccda399ba0dc203.jpg
#   inflating: /content/Datasets2/Pellet/JJ_CW_3_above500_5_jpg.rf.c3279af6acfdb2ddfa4c89fce75ee966.jpg
#   inflating: /content/Datasets2/Pellet/JJ_FT_2_212-500_10_jpg.rf.150da580789d7fce1b009c85746bc69a.jpg
#   inflating: /content/Datasets2/Pellet/JJ_FT_2_above500_2_jpg.rf.570710c3dd03a794ea3d7706fa34c181.jpg

# %%
import os
os.rename('/content/Datasets2','/content/Datasets')

# %%
#Count data
import os

# Define the paths to the directories
fiber_dir = "/content/Datasets/Fiber"
film_dir = "/content/Datasets/Film"
fragment_dir = "/content/Datasets/Fragment"
pellet_dir = "/content/Datasets/Pellet"

# Use the os module to count the number of files in each directory
fiber_count = len(os.listdir(fiber_dir))
film_count = len(os.listdir(film_dir))
fragment_count = len(os.listdir(fragment_dir))
pellet_count = len(os.listdir(pellet_dir))

# Print the results
print(f"Number of files in {fiber_dir}: {fiber_count}")
print(f"Number of files in {film_dir}: {film_count}")
print(f"Number of files in {fragment_dir}: {fragment_count}")
print(f"Number of files in {pellet_dir}: {pellet_count}")
# Out:
# Number of files in /content/Datasets/Fiber: 849
# Number of files in /content/Datasets/Film: 69
# Number of files in /content/Datasets/Fragment: 436
# Number of files in /content/Datasets/Pellet: 147

# %%
num_fiber = round(fiber_count*.15)
num_film = round(film_count*.15)
num_fragment = round(fragment_count*.15)
num_pellet = round(pellet_count*.15)

print(f"Validate for fiber : {num_fiber}")
print(f"Validate for fiber : {num_film}")
print(f"Validate for fiber : {num_fragment}")
print(f"Validate for fiber : {num_pellet}")
# Out:
# Validate for fiber : 127
# Validate for fiber : 10
# Validate for fiber : 65
# Validate for fiber : 22

# %%
import os
import random

# Define the paths to the source and test directories
source_dir = "/content/Datasets"
test_dir = "/content/test"

val_ratio = 0.2

# Define the number of files to select for each test category
num_fiber = round(fiber_count*val_ratio)
num_film = round(film_count*val_ratio)
num_fragment = round(fragment_count*val_ratio)
num_pellet = round(pellet_count*val_ratio)

# Define the paths to the source directories for each test category
fiber_dir = os.path.join(source_dir, "Fiber")
film_dir = os.path.join(source_dir, "Film")
fragment_dir = os.path.join(source_dir, "Fragment")
pellet_dir = os.path.join(source_dir, "Pellet")

# Define the paths to the test directories for each test category
fiber_test_dir = os.path.join(test_dir, "Fiber")
film_test_dir = os.path.join(test_dir, "Film")
fragment_test_dir = os.path.join(test_dir, "Fragment")
pellet_test_dir = os.path.join(test_dir, "Pellet")

# Create the test directories if they don't already exist
os.makedirs(fiber_test_dir, exist_ok=True)
os.makedirs(film_test_dir, exist_ok=True)
os.makedirs(fragment_test_dir, exist_ok=True)
os.makedirs(pellet_test_dir, exist_ok=True)

# Set the random seed for reproducibility
random.seed(42)

# Randomly select files from each source directory and move them to the corresponding test directory
fiber_files = random.sample(os.listdir(fiber_dir), num_fiber)
for f in fiber_files:
    src_file = os.path.join(fiber_dir, f)
    dst_file = os.path.join(fiber_test_dir, f)
    os.rename(src_file, dst_file)

film_files = random.sample(os.listdir(film_dir), num_film)
for f in film_files:
    src_file = os.path.join(film_dir, f)
    dst_file = os.path.join(film_test_dir, f)
    os.rename(src_file, dst_file)

fragment_files = random.sample(os.listdir(fragment_dir), num_fragment)
for f in fragment_files:
    src_file = os.path.join(fragment_dir, f)
    dst_file = os.path.join(fragment_test_dir, f)
    os.rename(src_file, dst_file)

pellet_files = random.sample(os.listdir(pellet_dir), num_pellet)
for f in pellet_files:
    src_file = os.path.join(pellet_dir, f)
    dst_file = os.path.join(pellet_test_dir, f)
    os.rename(src_file, dst_file)

# %%
#Count data
import os

# Define the paths to the directories
fiber_dir = "/content/Datasets/Fiber"
film_dir = "/content/Datasets/Film"
fragment_dir = "/content/Datasets/Fragment"
pellet_dir = "/content/Datasets/Pellet"

# Use the os module to count the number of files in each directory
fiber_count = len(os.listdir(fiber_dir))
film_count = len(os.listdir(film_dir))
fragment_count = len(os.listdir(fragment_dir))
pellet_count = len(os.listdir(pellet_dir))

# Print the results
print(f"Number of files in {fiber_dir}: {fiber_count}")
print(f"Number of files in {film_dir}: {film_count}")
print(f"Number of files in {fragment_dir}: {fragment_count}")
print(f"Number of files in {pellet_dir}: {pellet_count}")
# Out:
# Number of files in /content/Datasets/Fiber: 679
# Number of files in /content/Datasets/Film: 55
# Number of files in /content/Datasets/Fragment: 349
# Number of files in /content/Datasets/Pellet: 118

# %%
#Count data
import os

# Define the paths to the directories
fiber_dir = "/content/test/Fiber"
film_dir = "/content/test/Film"
fragment_dir = "/content/test/Fragment"
pellet_dir = "/content/test/Pellet"

# Use the os module to count the number of files in each directory
fiber_count = len(os.listdir(fiber_dir))
film_count = len(os.listdir(film_dir))
fragment_count = len(os.listdir(fragment_dir))
pellet_count = len(os.listdir(pellet_dir))

# Print the results
print(f"Number of files in {fiber_dir}: {fiber_count}")
print(f"Number of files in {film_dir}: {film_count}")
print(f"Number of files in {fragment_dir}: {fragment_count}")
print(f"Number of files in {pellet_dir}: {pellet_count}")
# Out:
# Number of files in /content/test/Fiber: 170
# Number of files in /content/test/Film: 14
# Number of files in /content/test/Fragment: 87
# Number of files in /content/test/Pellet: 29

# %% [markdown]
# #Install Timm

# %%
# Install Timm (Need to restart the runtime after finish install )
# !pip install git+https://github.com/rwightman/pytorch-image-models.git
# !pip install lightning transformers datasets evaluate pillow==9.2.0

# %%
import torch
import torch.nn as nn
import torchvision.transforms as T
from torch.utils.data import DataLoader, random_split, Dataset

# Pytorch Image model (TIMM) library: a library for state-of-the-art image classification
import timm
import timm.optim
import timm.scheduler
from timm.data import ImageDataset, create_dataset, create_loader
from timm.data.transforms_factory import create_transform

import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import classification_report
from PIL import Image

import evaluate

import numpy as np
import pandas as pd
from scipy import stats

from tqdm.notebook import tqdm

import glob

from sklearn.model_selection import StratifiedKFold,KFold

from lightning.fabric import Fabric

from copy import copy

import shutil

from sklearn.utils.class_weight import compute_class_weight

# %% [markdown]
# ##visualization Model

# %%
try:
    from torchinfo import summary
except:
    print("[INFO] Couldn't find torchinfo... installing it.")
    # !pip install -q torchinfo
    from torchinfo import summary

# %%
# Select model (List of available is shown above)
mobilenetv3_large_100 = "hf_hub:timm/mobilenetv3_large_100.miil_in21k_ft_in1k"
mobilenetv3_large_100_model= timm.create_model(mobilenetv3_large_100, pretrained=True, num_classes=4)
# Print a summary using torchinfo (uncomment for actual output)
summary(model=mobilenetv3_large_100_model,
        input_size=(16, 3, 224, 224), # make sure this is "input_size", not "input_shape"
        # col_names=["input_size"], # uncomment for smaller output
        col_names=["input_size", "output_size", "num_params", "trainable"],
        col_width=20,
        row_settings=["var_names"]
)

# %%
# Transform image data based on ImageNet's mean and std
transforms = {
    "train": T.Compose([
        T.Resize((224, 224)),
        T.ToTensor(),
        T.Normalize(mean=torch.tensor([0.4850, 0.4560, 0.4060]), std=torch.tensor([0.2290, 0.2240, 0.2250]))
    ]),
    "test": T.Compose([
        T.Resize((224, 224)),
        T.ToTensor(),
        T.Normalize(mean=torch.tensor([0.4850, 0.4560, 0.4060]), std=torch.tensor([0.2290, 0.2240, 0.2250]))
    ])
}

# %%
train_dir = '/content/Datasets'

# %%
# Use ImageFolder to create dataset(s)
from torchvision import datasets
dataset = datasets.ImageFolder(root=train_dir, # target folder of images
                                  transform=transforms["train"], # transforms to perform on data (images)
                                  target_transform=None) # transforms to perform on labels (if necessary)

# %%
dataset.class_to_idx

# %%
len(dataset)

# %%
# Select device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device

# %%
#Select Model
model_name = "hf_hub:timm/mobilenetv3_large_100.miil_in21k_ft_in1k"

# %%
num_epochs = 5
criterion = nn.CrossEntropyLoss()

# Cross Validation Configuration
k_splits = 5
metric = evaluate.load("accuracy")

# %%
# Cross validation
kf = KFold(n_splits=k_splits, shuffle=True, random_state=42)

# %%
# Gradient Accumulation Settings
# Set to 1 for no accumulation
train_batch_size = 16
eval_batch_size = 8
num_accumulate = 1

# %%
torch.set_float32_matmul_precision('high')
fabric = Fabric(accelerator="cuda", precision="16-mixed")
fabric.launch()

# %%
import time

# %%
# %%time
all_eval_scores = []

for fold, (train_idx, val_idx) in enumerate(kf.split(dataset)):
    print(f"Fold {fold+1} of {k_splits}")

    # Load Model
    model = timm.create_model(model_name, pretrained=True, num_classes=4)


    # Load Optimizer and Scheduler
    optimizer = timm.optim.create_optimizer_v2(model, opt="AdamW", lr=5e-4)
    # optimizer = timm.optim.Lookahead(optimizer, alpha=0.5, k=6)    # update the slow weight every k steps
                                                                   # update the optimizer by combine slow weight and fast weight * alpha

    model, optimizer = fabric.setup(model, optimizer)

    scheduler = timm.scheduler.create_scheduler_v2(optimizer, num_epochs=num_epochs)[0]

    # Load Data: split train and valition set based on kfold
    train_dataset = torch.utils.data.Subset(dataset, train_idx)
    val_dataset = torch.utils.data.Subset(dataset, val_idx)

    train_dataloader = DataLoader(train_dataset, batch_size=train_batch_size, shuffle=True, num_workers=4, pin_memory=True)
    val_dataloader = DataLoader(val_dataset, batch_size=eval_batch_size, shuffle=False, num_workers=4, pin_memory=True)

    train_dataloader, val_dataloader = fabric.setup_dataloaders(train_dataloader, val_dataloader)

    # Reset Model Info
    info = {
        "metric_train": [],
        "metric_val": [],
        "train_loss": [],
        "val_loss": [],
        "best_metric_val": -999,
        "best_val_loss": 999,
    }

    for epoch in range(num_epochs):
        train_loss_epoch = []
        val_loss_epoch = []

        train_preds = []
        train_targets = []

        val_preds = []
        val_targets = []

        num_updates = epoch * len(train_dataloader)

        ### === Train Loop === ###
        ## Time
        s1 = time.time()

        model.train()
        for idx, batch in enumerate(tqdm(train_dataloader)):
            inputs, targets = batch
            # inputs = {k: v.to(device) for k,v in inputs.items()}
            outputs = model(inputs)
            loss = criterion(outputs, targets)

            fabric.backward(loss)

            # === Gradient Accumulation === #
            if ((idx + 1) % num_accumulate == 0) or (idx + 1 == len(train_dataloader)):
                optimizer.step()
                scheduler.step_update(num_updates=num_updates)
                optimizer.zero_grad()
            # ============================= #

            train_loss_epoch.append(loss.item())
            train_preds += outputs.argmax(-1).detach().cpu().tolist()
            train_targets += targets.tolist()
        ### ==================== ###

        # optimizer.sync_lookahead()              # Sync slow weight and fast weight
        scheduler.step(epoch + 1)

        ### === Evaluation Loop === ###
        model.eval()
        with torch.no_grad():
            for batch in tqdm(val_dataloader):
                inputs, targets = batch
                # inputs = {k: v.to(device) for k,v in inputs.items()}
                outputs = model(inputs)
                loss = criterion(outputs, targets)

                # Log Values
                val_loss_epoch.append(loss.item())
                val_preds += outputs.argmax(-1).detach().cpu().tolist()
                val_targets += targets.tolist()
        ### ======================= ###
        ## Time train finish
        s2 = time.time()
        elapsed_time = s2 - s1


        # Log Data
        metric_train = metric.compute(predictions=train_preds, references=train_targets)["accuracy"]
        metric_val = metric.compute(predictions=val_preds, references=val_targets)["accuracy"]

        info["metric_train"].append(metric_train)
        info["metric_val"].append(metric_val)

        info["train_loss"].append(np.average(train_loss_epoch))
        info["val_loss"].append(np.average(val_loss_epoch))

        if metric_val > info["best_metric_val"]:
        # if info["val_loss"][-1] < info["best_val_loss"]:
            print("New Best Score!")
            # print("New Best Val Loss")
            info["best_metric_val"] = metric_val
            # info["best_val_loss"] = info["val_loss"][-1]
            torch.save(model, f"mobilenetv3_large_100_checkpoint_fold{fold}.pt")

        print(f"Using time of Fold: {fold} | Epoch: {epoch} | {elapsed_time} second ")
        print(info)
        print(f"Fold: {fold} | Epoch: {epoch} | Metric: {metric_val} | Training Loss: {np.average(train_loss_epoch)} | Validation Loss: {np.average(val_loss_epoch)}")

    # save all best metric val
    all_eval_scores.append(info["best_metric_val"])

# %%
classname = dataset.classes
classname

# %%
for fold in range(k_splits):
    predictions = []
    references = []

    # load model
    loaded_model = torch.load(f"mobilenetv3_large_100_checkpoint_fold{fold}.pt")
    # Evaluation
    loaded_model.eval()
    with torch.no_grad():
        for batch in tqdm(val_dataloader):
            inputs, targets = batch
            outputs = loaded_model(inputs.to(device))

            # Log Values
            predictions += outputs.argmax(-1).detach().cpu().tolist()
            references += targets.tolist()

    print(f"Fold: {fold}")

    # Confusion matrix
    cm = confusion_matrix(references, predictions)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=classname)
    disp.plot()
    plt.show()

    # Classification Report
    print(classification_report(references, predictions, target_names=classname))

# %%
classname = dataset.classes
classname

# %% [markdown]
# ###Verification by sepreate data

# %%
test_folder = '/content/test'

# %%
# Making Dataset
from torchvision import datasets
test_dataset = datasets.ImageFolder(root=test_folder, # target folder of images
                                  transform=transforms["test"], # transforms to perform on data (images)
                                  target_transform=None) # transforms to perform on labels (if necessary)

# %%
len(test_dataset)

# %%
# Making test dataloader
test_dataloader = DataLoader(test_dataset, batch_size=eval_batch_size, shuffle=False, num_workers=4, pin_memory=True)

# %%
test_dataset.classes

# %%
len(test_dataloader)

# %%
for fold in range(k_splits):
    predictions = []
    references = []

    # load model
    loaded_model = torch.load(f"mobilenetv3_large_100_checkpoint_fold{fold}.pt")
    # Evaluation
    loaded_model.eval()
    with torch.no_grad():
        for batch in tqdm(test_dataloader):
            inputs, targets = batch
            outputs = loaded_model(inputs.to(device))

            # Log Values
            predictions += outputs.argmax(-1).detach().cpu().tolist()
            references += targets.tolist()

    print(f"Fold: {fold}")

    # Confusion matrix
    cm = confusion_matrix(references, predictions)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=classname)
    disp.plot()
    plt.show()

    # Classification Report
    print(classification_report(references, predictions, target_names=classname))

# %% [markdown]
# ##Visualization train model result

# %%
## Making Pridcition return class & prob
from typing import List, Tuple

from PIL import Image
def pred_class(model: torch.nn.Module,
                        image_path: str,
                        class_names: List[str],
                        image_size: Tuple[int, int] = (224, 224),
                        transform: T = None,
                        device: torch.device=device):


    # 2. Open image
    img = Image.open(image_path)

    # 3. Create transformation for image (if one doesn't exist)
    if transform is not None:
        image_transform = transform
    else:
        image_transform = transforms.Compose([
            transforms.Resize(image_size),
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                 std=[0.229, 0.224, 0.225]),
        ])

    ### Predict on image ###

    # 4. Make sure the model is on the target device
    model.to(device)

    # 5. Turn on model evaluation mode and inference mode
    model.eval()
    with torch.inference_mode():
      # 6. Transform and add an extra dimension to image (model requires samples in [batch_size, color_channels, height, width])
      transformed_image = image_transform(img).unsqueeze(dim=0)

      # 7. Make a prediction on image with an extra dimension and send it to the target device
      target_image_pred = model(transformed_image.to(device))

    # 8. Convert logits -> prediction probabilities (using torch.softmax() for multi-class classification)
    target_image_pred_probs = torch.softmax(target_image_pred, dim=1)

    # 9. Convert prediction probabilities -> prediction labels
    target_image_pred_label = torch.argmax(target_image_pred_probs, dim=1)

    classname =  class_names[target_image_pred_label]
    prob = target_image_pred_probs.max().cpu().numpy()

    return classname , prob

# %%
##Load some model
loaded_model = torch.load('/content/mobilenetv3_large_100_checkpoint_fold0.pt')

# %% [markdown]
# ##Train data visulization

# %%
#Making df for random
import os
import pandas as pd
from PIL import Image

# create an empty list to store image paths
image_paths = []

# loop through each subfolder in the "Image" directory
for root, dirs, files in os.walk('/content/test'):
    for subfolder_name in dirs:
        # get the path to the subfolder
        subfolder_path = os.path.join(root, subfolder_name)
        # loop through each file in the subfolder
        for filename in os.listdir(subfolder_path):
            image_path = os.path.join(subfolder_path, filename)
            image_paths.append((image_path, subfolder_name))

# create a DataFrame from the list of image paths
df = pd.DataFrame(image_paths, columns=['path', 'subfolder_name'])

# %%
df.head()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image



def sample_picture(df=df,random_state=None):
    # Sample 20 random rows from the DataFrame
    sample_df = df.sample(20, random_state=random_state).copy()
    sample_df = sample_df.reset_index(drop=True)
    # Define the grid layout for displaying the images
    num_rows = 4
    num_cols = 5
    fig, axs = plt.subplots(num_rows, num_cols, figsize=(15, 12))
    fig.tight_layout(pad=5.0)

    # Iterate over the sampled rows and display the images in the grid
    for i, row in sample_df.iterrows():
        img = Image.open(row['path'])

        # Prediction
        pred_name , prob = pred_class(model=loaded_model,image_path=row['path'],
                   class_names = classname,
                   transform=transforms["test"])

        row_idx = i // num_cols
        col_idx = i % num_cols
        axs[row_idx, col_idx].imshow(img)
        axs[row_idx, col_idx].axis('on')
        axs[row_idx, col_idx].set_title(row['subfolder_name'] + ': \nPredict:' + pred_name + '\nProb:'+ str(prob.round(decimals=2)) )

        # prediction


    plt.show()

# %%
sample_picture()

# %%
sample_picture()

# %%
sample_picture()

# %%
sample_picture()

# %%
sample_picture()

# %%
sample_picture()

# %% [markdown]
# ## Outsite data testing

# %%
# !wget https://universe.roboflow.com/ds/fx3tNSqjNJ?key=N4VBuJEAJf

# %%
# !unzip /content/fx3tNSqjNJ?key=N4VBuJEAJf

# %%
import pandas as pd
train_df = pd.read_csv('/content/train/_classes.csv')

# %%
#Count all value in train data set
train_df[(train_df == 1)].sum()

# %%
#Sum all Sphere fiber fragment sheet sum = 1 if one class sum >1 is multiclass
train_df['Sum'] = train_df[' Sphere'] + train_df[' fiber'] + train_df[' fragment'] + train_df[' sheet']

# %%
# Count Multiclass pictures
train_df[(train_df['Sum']> 1)].count()

# %%
# Delete multiclass picture
train_df = train_df[train_df['Sum'] == 1]

# %%
# Count remain
train_df[(train_df == 1)].sum()

# %%
# Seperate in to dataset/Sphere , dataset/fiber, dataset/fragment, dataset/sheet,
import os
import shutil

# read the file names and classes into a pandas dataframe
df =train_df

# define the source and destination directories
src_dir = '/content/train'
dst_dir = '/content/dataset'

# loop through each row in the dataframe
for idx, row in df.iterrows():
    # get the filename and class label
    filename = row['filename']

    # check if the class label is 1
    if row[' Sphere'] == 1:
        # create the destination directory if it doesn't exist
        dst_subdir = os.path.join(dst_dir,'Sphere')
        os.makedirs(dst_subdir, exist_ok=True)

        # copy the file to the destination directory
        src_path = os.path.join(src_dir, filename)
        dst_path = os.path.join(dst_subdir, filename)
        shutil.copyfile(src_path, dst_path)
    elif row[' fiber'] == 1:
        # create the destination directory if it doesn't exist
        dst_subdir = os.path.join(dst_dir, 'fiber')
        os.makedirs(dst_subdir, exist_ok=True)

        # copy the file to the destination directory
        src_path = os.path.join(src_dir, filename)
        dst_path = os.path.join(dst_subdir, filename)
        shutil.copyfile(src_path, dst_path)
    elif row[' fragment'] == 1:
        # create the destination directory if it doesn't exist
        dst_subdir = os.path.join(dst_dir, 'fragment')
        os.makedirs(dst_subdir, exist_ok=True)

        # copy the file to the destination directory
        src_path = os.path.join(src_dir, filename)
        dst_path = os.path.join(dst_subdir, filename)
        shutil.copyfile(src_path, dst_path)
    elif row[' sheet'] == 1:
        # create the destination directory if it doesn't exist
        dst_subdir = os.path.join(dst_dir, 'sheet')
        os.makedirs(dst_subdir, exist_ok=True)

        # copy the file to the destination directory
        src_path = os.path.join(src_dir, filename)
        dst_path = os.path.join(dst_subdir, filename)
        shutil.copyfile(src_path, dst_path)

# %%
#Making df of another for random
import os
import pandas as pd
from PIL import Image

# create an empty list to store image paths
image_paths = []

# loop through each subfolder in the "Image" directory
for root, dirs, files in os.walk('/content/dataset'):
    for subfolder_name in dirs:
        # get the path to the subfolder
        subfolder_path = os.path.join(root, subfolder_name)
        # loop through each file in the subfolder
        for filename in os.listdir(subfolder_path):
            image_path = os.path.join(subfolder_path, filename)
            image_paths.append((image_path, subfolder_name))

# create a DataFrame from the list of image paths
other_df = pd.DataFrame(image_paths, columns=['path', 'subfolder_name'])

# %%
other_df.head()

# %%
sample_picture(df=other_df)

# %%
sample_picture(df=other_df)

# %%
sample_picture(df=other_df)

# %%
sample_picture(df=other_df)

# %%
sample_picture(df=other_df)

# %%
sample_picture(df=other_df)

# %%
sample_picture(df=other_df)

# %%
sample_picture(df=other_df)

# %%
sample_picture(df=other_df)

# %%
sample_picture(df=other_df)

# %%
sample_picture(df=other_df)

# %%
sample_picture(df=other_df)

# %%
# !cp /content/mobilenetv3_large_100_checkpoint_fold0.pt /content/drive/MyDrive/Datasets/Trial15_mobienetv3
# !cp /content/mobilenetv3_large_100_checkpoint_fold1.pt /content/drive/MyDrive/Datasets/Trial15_mobienetv3
# !cp /content/mobilenetv3_large_100_checkpoint_fold2.pt /content/drive/MyDrive/Datasets/Trial15_mobienetv3
# !cp /content/mobilenetv3_large_100_checkpoint_fold3.pt /content/drive/MyDrive/Datasets/Trial15_mobienetv3
# !cp /content/mobilenetv3_large_100_checkpoint_fold4.pt /content/drive/MyDrive/Datasets/Trial15_mobienetv3

# %%
# !nvidia-smi
